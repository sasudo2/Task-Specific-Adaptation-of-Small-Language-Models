# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/python-dataset-for-dsa-questions/cleaned_flytec.csv
# /kaggle/input/leetcode-with-desciption-and-code/leetcode_with_description_and_code.csv
# /kaggle/input/cleaned-datasets-of-alpaca/new version.csv
# /kaggle/input/taco-cleaned/taco_cleaned.csv

# %%
df1 = pd.read_csv("/kaggle/input/taco-cleaned/taco_cleaned.csv")
df2 = pd.read_csv("/kaggle/input/cleaned-datasets-of-alpaca/new version.csv")
df3 = pd.read_csv("/kaggle/input/python-dataset-for-dsa-questions/cleaned_flytec.csv")
df4 = pd.read_csv("/kaggle/input/leetcode-with-desciption-and-code/leetcode_with_description_and_code.csv")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1205 non-null   int64
#  1   id                 1205 non-null   int64
#  2   title              1205 non-null   object
#  3   description        1205 non-null   object
#  4   is_premium         1205 non-null   int64
#  5   difficulty         1205 non-null   object
#  6   solution_link      733 non-null    object
#  7   acceptance_rate    1205 non-null   float64
#  8   frequency          1205 non-null   float64
#  9   url                1205 non-null   object
#  10  discuss_count      1205 non-null   int64
#  11  accepted           1205 non-null   object
#  12  submissions        1205 non-null   object
#  13  companies          1167 non-null   object
#  14  related_topics     1144 non-null   object
#  15  likes              1205 non-null   int64
# ...

# %%
df4.head()
# Out:
#    Unnamed: 0  id                                           title  \
# 0           0   1                                         Two Sum
# 1           1   2                                 Add Two Numbers
# 2           2   3  Longest Substring Without Repeating Characters
# 3           3   4                     Median of Two Sorted Arrays
# 4           4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# ...

# %%
df4 = df4[['description','code']]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  1205 non-null   object
#  1   code         1205 non-null   object
# dtypes: object(2)
# memory usage: 19.0+ KB

# %%
df4 = df4.iloc[175:]

# %%
df4.head()
# Out:
#                                            description  \
# 175  A trie (pronounced as "try") or prefix tree is...
# 176  Given an array of positive integers `nums` and...
# 177  There are a total of `n` courses you have to t...
# 178  Design a data structure that supports adding n...
# 179  Given an `m x n` `board` of characters and a l...
#
#                                                   code
# 175  class Node:\n    def __init__(self):\n        ...
# 176  class Solution:\n    def minSubArrayLen(self, ...
# 177  class Solution:\n    def topologicalSort(self,...
# 178  class Node:\n    def __init__(self, val=None, ...
# 179  class Node:\n  def __init__(self):\n    self.c...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11926 entries, 0 to 11925
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          11926 non-null  int64
#  1   instruction         11926 non-null  object
#  2   input               8757 non-null   object
#  3   output              11926 non-null  object
#  4   prompt              11926 non-null  object
#  5   classification_raw  11926 non-null  object
#  6   category            11926 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 652.3+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20493 entries, 0 to 20492
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   question    20493 non-null  object
#  1   solutions   20493 non-null  object
#  2   difficulty  20493 non-null  object
#  3   tags        20493 non-null  object
# dtypes: object(4)
# memory usage: 640.5+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9617 entries, 0 to 9616
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  9617 non-null   object
#  1   code         9617 non-null   object
#  2   category     9617 non-null   object
# dtypes: object(3)
# memory usage: 225.5+ KB

# %%
df3 = df3[['instruction','code']]

# %%
df2.head()
# Out:
#    Unnamed: 0                                        instruction  \
# 0           0  Create a function to calculate the sum of a se...
# 1           3   Generate a python script to perform this action.
# 2           4  Write a python script to generates random numb...
# 3           5  Write a Python code to get the third largest e...
# 4           7  Create a Python function that takes in a strin...
#
#                                                input  \
# 0                                    [1, 2, 3, 4, 5]
# 1  Given a string, remove all the consecutive dup...
# 2                                                NaN
# 3                           [12, 13, 13, 45, 22, 99]
# 4           'This is a test', ['test', 'this', 'is']
#
#                                               output  \
# 0  # Python code\ndef sum_sequence(sequence):\n  ...
# 1  def remove_duplicates(string): \n    result = ...
# 2  def generate_random_divisible_number():\n    i...
# ...

# %%
df2 = df2[['instruction','output']]

# %%
df1.head()
# Out:
#                                             question  \
# 0  The city park of IT City contains n east to we...
# 1  Zookeeper is buying a carton of fruit to feed ...
# 2  Sasha and Kolya decided to get drunk with Coke...
# 3  Read problem statements in [Hindi], [Bengali],...
# 4  I started this as a joke among friends, tellin...
#
#                                            solutions   difficulty  \
# 0  n = int(input())\ncn5 = n * (n - 1) // 2 * (n ...       MEDIUM
# 1  hist = [0] * 1000005\n\ndef solve(n, s):\n\tto...    VERY_HARD
# 2  from collections import deque\nMAX_A = 1000\n\...         HARD
# 3  p = 10 ** 9 + 7\n\ndef power(a, n):\n\tres = 1...  MEDIUM_HARD
# 4  from math import *\nDIGS = '0123456789ABCDEFGH...  MEDIUM_HARD
#
#                                                 tags
# 0                   ['Combinatorics', 'Mathematics']
# 1  ['Sorting', 'Amortized analysis', 'Dynamic pro...
# 2  ['Graph algorithms', 'Graph traversal', 'Short...
# ...

# %%
df1 = df1[['question','solutions']]

# %%
print(df1.info(),df2.info(),df3.info(),df4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20493 entries, 0 to 20492
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   question   20493 non-null  object
#  1   solutions  20493 non-null  object
# dtypes: object(2)
# memory usage: 320.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11926 entries, 0 to 11925
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  11926 non-null  object
#  1   output       11926 non-null  object
# dtypes: object(2)
# memory usage: 186.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9617 entries, 0 to 9616
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  9617 non-null   object
#  1   code         9617 non-null   object
# dtypes: object(2)
# memory usage: 150.4+ KB
# ...

# %%
df1 = df1.rename(columns={'question': 'instruction', 'solutions': 'code'})
df2 = df2.rename(columns={'instruction': 'instruction', 'output': 'code'})
df4 = df4.rename(columns={'description':'instruction','code':'code'})

# %%
combined_df = pd.concat([df1, df2, df3,df4], ignore_index=True)

# %%
combined_df.head()
# Out:
#                                          instruction  \
# 0  The city park of IT City contains n east to we...
# 1  Zookeeper is buying a carton of fruit to feed ...
# 2  Sasha and Kolya decided to get drunk with Coke...
# 3  Read problem statements in [Hindi], [Bengali],...
# 4  I started this as a joke among friends, tellin...
#
#                                                 code
# 0  n = int(input())\ncn5 = n * (n - 1) // 2 * (n ...
# 1  hist = [0] * 1000005\n\ndef solve(n, s):\n\tto...
# 2  from collections import deque\nMAX_A = 1000\n\...
# 3  p = 10 ** 9 + 7\n\ndef power(a, n):\n\tres = 1...
# 4  from math import *\nDIGS = '0123456789ABCDEFGH...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43066 entries, 0 to 43065
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  43066 non-null  object
#  1   code         43066 non-null  object
# dtypes: object(2)
# memory usage: 673.0+ KB

# %%
def complexity_filter(df, text_col='code', min_words=7, max_repeat_ratio=0.6):
    df = df[df[text_col].str.split().str.len() > min_words]
    def repetition_ratio(text):
        words = text.split()
        return 1.0 - (len(set(words)) / len(words)) if len(words) > 0 else 0
    df = df[df[text_col].apply(repetition_ratio) < max_repeat_ratio]
    return df

combined_df = complexity_filter(combined_df)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39823 entries, 1 to 43065
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  39823 non-null  object
#  1   code         39823 non-null  object
# dtypes: object(2)
# memory usage: 933.4+ KB

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import MiniBatchKMeans
import numpy as np

def diversity_sampling(df, text_col='instruction', num_clusters=21000):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(
        df[text_col].tolist(),
        show_progress_bar=True,
        normalize_embeddings=True
    )

    kmeans = MiniBatchKMeans(
        n_clusters=num_clusters,
        batch_size=1024,
        random_state=42
    )
    
    clusters = kmeans.fit_predict(embeddings)
    df['cluster'] = clusters

    # Compute distance to centroid
    distances = np.linalg.norm(
        embeddings - kmeans.cluster_centers_[clusters],
        axis=1
    )

    df['distance'] = distances
    print(df['distance'].describe())
    curated_df = df.loc[df.groupby('cluster')['distance'].idxmin()]

    return curated_df.drop(columns=['cluster', 'distance'])
combined_df = diversity_sampling(combined_df)
# Out:
# 2026-01-31 10:20:03.224497: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769854803.433821      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769854803.492371      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769854804.010524      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18596 entries, 34038 to 33383
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  18596 non-null  object
#  1   code         18596 non-null  object
# dtypes: object(2)
# memory usage: 435.8+ KB

# %%
shuffled_df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
shuffled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18596 entries, 0 to 18595
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  18596 non-null  object
#  1   code         18596 non-null  object
# dtypes: object(2)
# memory usage: 290.7+ KB

# %%
train = shuffled_df.iloc[0:16736]

# %%
test = shuffled_df.iloc[16736:]

# %%
test.head()
# Out:
#                                              instruction  \
# 16736  Create a Python function which takes a string ...
# 16737  Create a Python function to remove all the ele...
# 16738  Optimize the following code using functional p...
# 16739                      List the mounted file systems
# 16740  Provide a solution using Python to capitalize ...
#
#                                                     code
# 16736  def word_freq(s):\n \n # Create an empty dicti...
# 16737  def remove_greater_than(arr, value):\n    new_...
# 16738  def add_odds(list):\n  odd_list = filter(lambd...
# 16739  ```python\nimport os\nmounted_file_systems = o...
# 16740  ```python\ndef capitalize(phrase):\n  words = ...

# %%
import json

SYSTEM_PROMPT = """You are an expert Python programmer. Your task is to generate correct, efficient Python code.
- Write only the function implementation
- Do not include markdown code blocks
- Do not include explanations
- The code must be syntactically correct
- There must be proper indentation.
- always enclose code only between ``` and ```
- Do not reason
- Do not give any examples
"""

def format_llama(inst, code):
    return (
        "<s>[INST] <<SYS>>\n"
        f"{SYSTEM_PROMPT}\n"
        "<</SYS>>\n"
        f"{inst} [/INST] ```\n{code}``` </s>"
    )
with open("train.jsonl", "w", encoding="utf-8") as f:
    for _, row in train.iterrows():
        formatted_text = format_llama(
            str(row["instruction"]),
            str(row["code"])
        )
        obj = {"text": formatted_text}
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

print("JSONL file created: train.jsonl")
# Out:
# JSONL file created: train.jsonl

# %%
import json

SYSTEM_PROMPT = """You are an expert Python programmer. Your task is to generate correct, efficient Python code.
- Write only the function implementation
- Do not include markdown code blocks
- Do not include explanations
- The code must be syntactically correct
- There must be proper indentation.
- always enclose code only between ``` and ```
- Do not reason
- Do not give any examples
"""

def format_llama(inst, code):
    return (
        "<s>[INST] <<SYS>>\n"
        f"{SYSTEM_PROMPT}\n"
        "<</SYS>>\n"
        f"{inst} [/INST] ```\n{code}``` </s>"
    )

with open("test.jsonl", "w", encoding="utf-8") as f:
    for _, row in test.iterrows():
        formatted_text = format_llama(
            str(row["instruction"]),
            str(row["code"])
        )
        obj = {"text": formatted_text}
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

print("JSONL file created: test.jsonl")
# Out:
# JSONL file created: test.jsonl
