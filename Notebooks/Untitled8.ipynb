# %%
# !pip install -q sentence-transformers tqdm

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/alpaca_python_code.csv', engine='python', on_bad_lines='skip')

# %%
# !pip install -q ollama nest_asyncio
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os
import time
import nest_asyncio
from ollama import AsyncClient
import pandas as pd
import asyncio
import subprocess


nest_asyncio.apply()
MODEL_NAME = "qwen2.5-coder:1.5b"
os.system("pkill ollama")
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(15)
os.system(f"ollama pull {MODEL_NAME}")
BATCH_SIZE = 5
async def classify_row(client, idx, instruction, code):
    prompt = f"""
Classify into ONE Broad Category: [array,graph,tree,sorting,searching,hashmap,dynamic programming,string,Web Dev,Machine Learning]
Task: {str(instruction)[:400]}
Code: {str(code)[:300]}
Return ONLY:
Category
"""
    try:
        response = await client.generate(model=MODEL_NAME, prompt=prompt, options={"temperature": 0})
        text = response['response'].strip().split("\n")[0]
        # Live feedback
        print(f"\nRow {idx+1}: Predicted -> {text}")
        return idx, text
    except Exception as e:
        print(f"\nRow {idx+1}: ERROR -> {e}")
        return idx, f"Error | {str(e)[:50]}"

async def run_pipeline(df):
    client = AsyncClient()
    tasks = [classify_row(client, idx, row['instruction'], row['output']) for idx, row in df.iterrows()]

    results = []
    for i in range(0, len(tasks), BATCH_SIZE):
        batch = tasks[i:i+BATCH_SIZE]
        batch_results = await asyncio.gather(*batch)
        results.extend(batch_results)
        print(f"Processed {min(i+BATCH_SIZE, len(df))}/{len(df)} rows so far")
    return results


print("Starting classification...\n")
final_results = await run_pipeline(df)
results_dict = dict(final_results)
df["classification_raw"] = df.index.map(results_dict)
df[["category", "topic"]] = df["classification_raw"].str.split("|", n=1, expand=True)
df["category"] = df["category"].str.strip()
df["topic"] = df["topic"].str.strip()
print("\nClassification Complete!")
print("\nCategory counts:")
print(df["category"].value_counts())
print("\n--- Sample Predictions ---")
for i in range(min(5, len(df))):
    print(f"\nInstruction: {df.loc[i, 'instruction']}")
    print(f"Code: {df.loc[i, 'output'][:200]}...")
    print(f"Predicted: {df.loc[i, 'classification_raw']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed 16340/18612 rows so far
#
# Row 16342: Predicted -> Graph
#
# Row 16341: Predicted -> Tree
#
# Row 16345: Predicted -> Machine Learning
#
# Row 16343: Predicted -> Sorting
#
# Row 16344: Predicted -> Sorting
# Processed 16345/18612 rows so far
#
# Row 16346: Predicted -> string
#
# Row 16349: Predicted -> Machine Learning
#
# Row 16350: Predicted -> Task
#
# Row 16348: Predicted -> Data Structure
#
# Row 16347: Predicted -> Sorting
# Processed 16350/18612 rows so far
#
# Row 16352: Predicted -> Task Management
#
# Row 16353: Predicted -> Array
#
# Row 16355: Predicted -> Sorting
#
# Row 16351: Predicted -> Sorting
#
# Row 16354: Predicted -> Graph
# Processed 16355/18612 rows so far
#
# Row 16360: Predicted -> Array
#
# Row 16358: Predicted -> Tree
#
# Row 16359: Predicted -> string
#
# Row 16356: Predicted -> Sorting
#
# Row 16357: Predicted -> Book
# Processed 16360/18612 rows so far
#
# Row 16364: Predicted -> searching
#
# Row 16362: Predicted -> Category: Clustering
#
# Row 16363: Predicted -> set
#
# Row 16365: Predicted -> Sorting
#
# Row 16361: Predicted -> Graph
# Processed 16365/18612 rows so far
#
# Row 16368: Predicted -> Machine Learning
#
# Row 16367: Predicted -> Mathematical Operations
#
# Row 16366: Predicted -> Sorting
#
# Row 16369: Predicted -> Hashmap
#
# Row 16370: Predicted -> searching
# Processed 16370/18612 rows so far
#
# Row 16375: Predicted -> Number Theory
#
# Row 16374: Predicted -> Tree
#
# Row 16371: Predicted -> Sorting
#
# Row 16372: Predicted -> Mathematical Calculation
#
# Row 16373: Predicted -> string
# Processed 16375/18612 rows so far
#
# Row 16376: Predicted -> Category: string
#
# Row 16377: Predicted -> Mathematical Calculation
#
# Row 16380: Predicted -> Sorting
#
# Row 16379: Predicted -> string
#
# Row 16378: Predicted -> Sorting
# Processed 16380/18612 rows so far
#
# Row 16383: Predicted -> string
#
# Row 16384: Predicted -> Sorting
#
# Row 16382: Predicted -> Tree
#
# Row 16385: Predicted -> Tree
#
# Row 16381: Predicted -> Machine Learning
# Processed 16385/18612 rows so far
#
# Row 16386: Predicted -> Web Dev
#
# Row 16389: Predicted -> Security
#
# Row 16390: Predicted -> Sorting
#
# Row 16387: Predicted -> Sorting
#
# Row 16388: Predicted -> Mathematical Calculation
# Processed 16390/18612 rows so far
#
# Row 16392: Predicted -> Sorting
#
# Row 16391: Predicted -> Number Theory
#
# Row 16395: Predicted -> string
#
# Row 16393: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 16394: Predicted -> string
# Processed 16395/18612 rows so far
#
# Row 16399: Predicted -> Database
#
# Row 16397: Predicted -> Language Translation
#
# Row 16400: Predicted -> Data Analysis
#
# Row 16398: Predicted -> Number Theory
#
# Row 16396: Predicted -> Array
# Processed 16400/18612 rows so far
#
# Row 16403: Predicted -> Currency Conversion
#
# Row 16405: Predicted -> Tree
#
# Row 16402: Predicted -> Data Structure
#
# Row 16401: Predicted -> Array
#
# Row 16404: Predicted -> Array
# Processed 16405/18612 rows so far
#
# Row 16407: Predicted -> String
#
# Row 16406: Predicted -> string
#
# Row 16408: Predicted -> Machine Learning
#
# Row 16410: Predicted -> string
#
# Row 16409: Predicted -> Mathematical Expression
# Processed 16410/18612 rows so far
#
# Row 16413: Predicted -> tree
#
# Row 16415: Predicted -> string
#
# Row 16412: Predicted -> Mathematical Calculation
#
# Row 16414: Predicted -> Dictionary
#
# Row 16411: Predicted -> Sorting
# Processed 16415/18612 rows so far
#
# Row 16418: Predicted -> Sorting
#
# Row 16419: Predicted -> string
#
# Row 16420: Predicted -> string
#
# Row 16417: Predicted -> Data Structure
#
# Row 16416: Predicted -> Classification: Object Oriented Programming (OOP)
# Processed 16420/18612 rows so far
#
# Row 16424: Predicted -> Database Management
#
# Row 16425: Predicted -> Mathematical Calculation
#
# Row 16423: Predicted -> geometry
#
# Row 16422: Predicted -> Data Structure
#
# Row 16421: Predicted -> Sorting
# Processed 16425/18612 rows so far
#
# Row 16427: Predicted -> Matrix Manipulation
#
# Row 16429: Predicted -> Sorting
#
# Row 16428: Predicted -> Graph
#
# Row 16430: Predicted -> Sorting
#
# Row 16426: Predicted -> Web Dev
# Processed 16430/18612 rows so far
#
# Row 16431: Predicted -> Data Manipulation
#
# Row 16435: Predicted -> Sorting
#
# Row 16433: Predicted -> Sorting
#
# Row 16432: Predicted -> Mathematical Calculation
#
# Row 16434: Predicted -> Date
# Processed 16435/18612 rows so far
#
# Row 16438: Predicted -> Sorting
#
# Row 16440: Predicted -> Sorting
#
# Row 16437: Predicted -> Sorting
#
# Row 16439: Predicted -> Machine Learning
#
# Row 16436: Predicted -> Web Dev
# Processed 16440/18612 rows so far
#
# Row 16443: Predicted -> Mathematical Calculation
#
# Row 16441: Predicted -> Temperature Conversion
#
# Row 16444: Predicted -> Text Mining
#
# Row 16442: Predicted -> Clustering
#
# Row 16445: Predicted -> Sorting
# Processed 16445/18612 rows so far
#
# Row 16450: Predicted -> Mathematical Operations
#
# Row 16446: Predicted -> Graph
#
# Row 16448: Predicted -> Sorting
#
# Row 16449: Predicted -> Category: Statistics
#
# Row 16447: Predicted -> Data Structure
# Processed 16450/18612 rows so far
#
# Row 16451: Predicted -> Sorting
#
# Row 16454: Predicted -> string
#
# Row 16452: Predicted -> Game
#
# Row 16455: Predicted -> Dictionary comprehension
#
# Row 16453: Predicted -> Web Dev
# Processed 16455/18612 rows so far
#
# Row 16457: Predicted -> Database
#
# Row 16456: Predicted -> String
#
# Row 16459: Predicted -> String
#
# Row 16458: Predicted -> Machine Learning
#
# Row 16460: Predicted -> Sorting
# Processed 16460/18612 rows so far
#
# Row 16462: Predicted -> Graph
#
# Row 16463: Predicted -> Temperature Conversion
#
# Row 16461: Predicted -> searching
#
# Row 16464: Predicted -> string
#
# Row 16465: Predicted -> Sorting
# Processed 16465/18612 rows so far
#
# Row 16469: Predicted -> Sorting
#
# Row 16466: Predicted -> Sorting
#
# Row 16467: Predicted -> string
#
# Row 16470: Predicted -> Bank Account
#
# Row 16468: Predicted -> Machine Learning
# Processed 16470/18612 rows so far
#
# Row 16473: Predicted -> Tree
#
# Row 16472: Predicted -> Number Theory
#
# Row 16474: Predicted -> Tree
#
# Row 16475: Predicted -> Sorting
#
# Row 16471: Predicted -> Array
# Processed 16475/18612 rows so far
#
# Row 16477: Predicted -> string
#
# Row 16479: Predicted -> Array
#
# Row 16476: Predicted -> tree
#
# Row 16478: Predicted -> Sorting
#
# Row 16480: Predicted -> Number Theory
# Processed 16480/18612 rows so far
#
# Row 16481: Predicted -> Combination
#
# Row 16485: Predicted -> searching
#
# Row 16483: Predicted -> Tree
#
# Row 16484: Predicted -> Game
#
# Row 16482: Predicted -> String
# Processed 16485/18612 rows so far
#
# Row 16487: Predicted -> Encryption
#
# Row 16486: Predicted -> Sorting
#
# Row 16488: Predicted -> Number Theory
#
# Row 16489: Predicted -> Vector
#
# Row 16490: Predicted -> Tree
# Processed 16490/18612 rows so far
#
# Row 16493: Predicted -> Sorting
#
# Row 16491: Predicted -> Sorting
#
# Row 16494: Predicted -> Text Processing
#
# Row 16495: Predicted -> Sorting
#
# Row 16492: Predicted -> Machine Learning
# Processed 16495/18612 rows so far
#
# Row 16499: Predicted -> String
#
# Row 16496: Predicted -> Sorting
#
# Row 16497: Predicted -> searching
#
# Row 16498: Predicted -> Sorting
#
# Row 16500: Predicted -> Sorting
# Processed 16500/18612 rows so far
#
# Row 16503: Predicted -> Database
#
# Row 16505: Predicted -> Sorting
#
# Row 16504: Predicted -> Sorting
#
# Row 16502: Predicted -> Classification: Object-Oriented Programming (OOP)
#
# Row 16501: Predicted -> Sorting
# Processed 16505/18612 rows so far
#
# Row 16506: Predicted -> string
#
# Row 16507: Predicted -> Mathematical Calculation
#
# Row 16510: Predicted -> String
#
# Row 16508: Predicted -> Array
#
# Row 16509: Predicted -> Web Dev
# Processed 16510/18612 rows so far
#
# Row 16512: Predicted -> Machine Learning
#
# Row 16515: Predicted -> Game
#
# Row 16511: Predicted -> Sorting
#
# Row 16513: Predicted -> Sorting
#
# Row 16514: Predicted -> Sorting
# Processed 16515/18612 rows so far
#
# Row 16518: Predicted -> Machine Learning
#
# Row 16517: Predicted -> Sorting
#
# Row 16520: Predicted -> Sorting
#
# Row 16516: Predicted -> Sorting
#
# Row 16519: Predicted -> Tree
# Processed 16520/18612 rows so far
#
# Row 16522: Predicted -> Web Dev
#
# Row 16521: Predicted -> string
#
# Row 16524: Predicted -> math
#
# Row 16525: Predicted -> Machine Learning
#
# Row 16523: Predicted -> Mathematical Calculation
# Processed 16525/18612 rows so far
#
# Row 16526: Predicted -> Sorting
#
# Row 16527: Predicted -> Machine Learning
#
# Row 16529: Predicted -> Dictionary
#
# Row 16530: Predicted -> Sentiment Analysis
#
# Row 16528: Predicted -> Web Dev
# Processed 16530/18612 rows so far
#
# Row 16532: Predicted -> Web Dev
#
# Row 16535: Predicted -> Sorting
#
# Row 16533: Predicted -> string
#
# Row 16534: Predicted -> Sorting
#
# Row 16531: Predicted -> string
# Processed 16535/18612 rows so far
#
# Row 16539: Predicted -> Sorting
#
# Row 16536: Predicted -> Dynamic Programming
#
# Row 16540: Predicted -> Sorting
#
# Row 16538: Predicted -> searching
#
# Row 16537: Predicted -> Date Manipulation
# Processed 16540/18612 rows so far
#
# Row 16543: Predicted -> Machine Learning
#
# Row 16542: Predicted -> Sorting
#
# Row 16544: Predicted -> Sorting
#
# Row 16545: Predicted -> Web Dev
#
# Row 16541: Predicted -> geometry
# Processed 16545/18612 rows so far
#
# Row 16547: Predicted -> Tree
#
# Row 16550: Predicted -> tree
#
# Row 16549: Predicted -> Geometry
#
# Row 16546: Predicted -> Dictionary
#
# Row 16548: Predicted -> Sorting
# Processed 16550/18612 rows so far
#
# Row 16554: Predicted -> Mathematical Calculation
#
# Row 16553: Predicted -> Sorting
#
# Row 16552: Predicted -> Tree
#
# Row 16555: Predicted -> string
#
# Row 16551: Predicted -> Mathematical Operations
# Processed 16555/18612 rows so far
#
# Row 16559: Predicted -> Sorting
#
# Row 16558: Predicted -> Array
#
# Row 16556: Predicted -> Machine Learning
#
# Row 16557: Predicted -> string
#
# Row 16560: Predicted -> Web Dev
# Processed 16560/18612 rows so far
#
# Row 16565: Predicted -> searching
#
# Row 16564: Predicted -> Directory
#
# Row 16563: Predicted -> Network
#
# Row 16561: Predicted -> Sorting
#
# Row 16562: Predicted -> Sorting
# Processed 16565/18612 rows so far
#
# Row 16570: Predicted -> Sorting
#
# Row 16568: Predicted -> Array
#
# Row 16567: Predicted -> string
#
# Row 16566: Predicted -> Matrix
#
# Row 16569: Predicted -> Sorting
# Processed 16570/18612 rows so far
#
# Row 16571: Predicted -> Text Editor
#
# Row 16573: Predicted -> searching
#
# Row 16572: Predicted -> Sorting
#
# Row 16575: Predicted -> Sorting
#
# Row 16574: Predicted -> Sorting
# Processed 16575/18612 rows so far
#
# Row 16578: Predicted -> Classification: [object]
#
# Row 16576: Predicted -> Classification: [object]
#
# Row 16577: Predicted -> Integration
#
# Row 16580: Predicted -> Array
#
# Row 16579: Predicted -> Sorting
# Processed 16580/18612 rows so far
#
# Row 16582: Predicted -> Sorting
#
# Row 16581: Predicted -> Mathematical Calculation
#
# Row 16585: Predicted -> Statistics
#
# Row 16583: Predicted -> Graph
#
# Row 16584: Predicted -> Sorting
# Processed 16585/18612 rows so far
#
# Row 16586: Predicted -> Mathematical Operations
#
# Row 16587: Predicted -> Array
#
# Row 16589: Predicted -> Sorting
#
# Row 16588: Predicted -> Web Dev
#
# Row 16590: Predicted -> Web Dev
# Processed 16590/18612 rows so far
#
# Row 16595: Predicted -> Sorting
#
# Row 16591: Predicted -> dictionary
#
# Row 16594: Predicted -> Sorting
#
# Row 16592: Predicted -> Database
#
# Row 16593: Predicted -> Sorting
# Processed 16595/18612 rows so far
#
# Row 16596: Predicted -> Dictionary
#
# Row 16600: Predicted -> Array
#
# Row 16599: Predicted -> Text Analysis
#
# Row 16598: Predicted -> Number Theory
#
# Row 16597: Predicted -> Classification: Object Serialization
# Processed 16600/18612 rows so far
#
# Row 16602: Predicted -> Database
#
# Row 16604: Predicted -> Point
#
# Row 16603: Predicted -> Sorting
#
# Row 16601: Predicted -> Number Theory
#
# Row 16605: Predicted -> Sorting
# Processed 16605/18612 rows so far
#
# Row 16610: Predicted -> Data Structure
#
# Row 16606: Predicted -> Neural Network
#
# Row 16607: Predicted -> string
#
# Row 16609: Predicted -> Mathematical Calculation
#
# Row 16608: Predicted -> Mathematical Calculation
# Processed 16610/18612 rows so far
#
# Row 16613: Predicted -> Sorting
#
# Row 16612: Predicted -> String
#
# Row 16615: Predicted -> tree
#
# Row 16611: Predicted -> searching
#
# Row 16614: Predicted -> tree
# Processed 16615/18612 rows so far
#
# Row 16616: Predicted -> Array
#
# Row 16617: Predicted -> Number Theory
#
# Row 16618: Predicted -> Sorting
#
# Row 16620: Predicted -> Category: string
#
# Row 16619: Predicted -> Sorting
# Processed 16620/18612 rows so far
#
# Row 16621: Predicted -> Sorting
#
# Row 16624: Predicted -> Sorting
#
# Row 16622: Predicted -> tree
#
# Row 16625: Predicted -> Email Migration Script
#
# Row 16623: Predicted -> string
# Processed 16625/18612 rows so far
#
# Row 16626: Predicted -> Sorting
#
# Row 16627: Predicted -> Sorting
#
# Row 16629: Predicted -> string
#
# Row 16630: Predicted -> string
#
# Row 16628: Predicted -> Web Dev
# Processed 16630/18612 rows so far
#
# Row 16631: Predicted -> Web Dev
#
# Row 16632: Predicted -> Mathematical Calculation
#
# Row 16634: Predicted -> Sorting
#
# Row 16633: Predicted -> Algorithm
#
# Row 16635: Predicted -> Mathematical Calculation
# Processed 16635/18612 rows so far
#
# Row 16636: Predicted -> Sorting
#
# Row 16637: Predicted -> geometry
#
# Row 16639: Predicted -> Sorting
#
# Row 16638: Predicted -> Sorting
#
# Row 16640: Predicted -> string
# Processed 16640/18612 rows so far
#
# Row 16642: Predicted -> Sorting
#
# Row 16641: Predicted -> Tree
#
# Row 16644: Predicted -> Sorting
#
# Row 16643: Predicted -> Mathematical Calculation
#
# Row 16645: Predicted -> Sorting
# Processed 16645/18612 rows so far
#
# Row 16646: Predicted -> Category: Parallel Processing
#
# Row 16649: Predicted -> Machine Learning
#
# Row 16647: Predicted -> Sorting
#
# Row 16648: Predicted -> Sorting
#
# Row 16650: Predicted -> Tree
# Processed 16650/18612 rows so far
#
# Row 16651: Predicted -> Sorting
#
# Row 16652: Predicted -> Sentiment Analysis
#
# Row 16653: Predicted -> set
#
# Row 16654: Predicted -> String
#
# Row 16655: Predicted -> string
# Processed 16655/18612 rows so far
#
# Row 16658: Predicted -> Web Dev
#
# Row 16659: Predicted -> Sorting
#
# Row 16656: Predicted -> Table
#
# Row 16660: Predicted -> string
#
# Row 16657: Predicted -> string
# Processed 16660/18612 rows so far
#
# Row 16662: Predicted -> Sorting
#
# Row 16661: Predicted -> String
#
# Row 16663: Predicted -> Sorting
#
# Row 16664: Predicted -> Sorting
#
# Row 16665: Predicted -> Tree
# Processed 16665/18612 rows so far
#
# Row 16667: Predicted -> Tree
#
# Row 16668: Predicted -> Book
#
# Row 16669: Predicted -> Number Theory
#
# Row 16666: Predicted -> String
#
# Row 16670: Predicted -> Classification: Object Oriented Programming (OOP)
# Processed 16670/18612 rows so far
#
# Row 16674: Predicted -> Machine Learning
#
# Row 16671: Predicted -> Sorting
#
# Row 16672: Predicted -> Mathematical Calculation
#
# Row 16673: Predicted -> Sorting
#
# Row 16675: Predicted -> Tree
# Processed 16675/18612 rows so far
#
# Row 16677: Predicted -> Optimization
#
# Row 16680: Predicted -> Sorting
#
# Row 16676: Predicted -> Number Theory
#
# Row 16678: Predicted -> Sorting
#
# Row 16679: Predicted -> string
# Processed 16680/18612 rows so far
#
# Row 16681: Predicted -> string
#
# Row 16682: Predicted -> Mathematical Calculation
#
# Row 16684: Predicted -> Mathematical Calculation
#
# Row 16685: Predicted -> Programming Language
#
# Row 16683: Predicted -> Sorting
# Processed 16685/18612 rows so far
#
# Row 16689: Predicted -> Sorting
#
# Row 16686: Predicted -> Sorting
#
# Row 16690: Predicted -> Machine Learning
#
# Row 16687: Predicted -> searching
#
# Row 16688: Predicted -> Number Theory
# Processed 16690/18612 rows so far
#
# Row 16694: Predicted -> Array
#
# Row 16691: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 16695: Predicted -> Sorting
#
# Row 16693: Predicted -> Sorting
#
# Row 16692: Predicted -> Web Dev
# Processed 16695/18612 rows so far
#
# Row 16699: Predicted -> Web Dev
#
# Row 16696: Predicted -> tree
#
# Row 16697: Predicted -> Sorting
#
# Row 16700: Predicted -> Tree
#
# Row 16698: Predicted -> Number Theory
# Processed 16700/18612 rows so far
#
# Row 16702: Predicted -> Machine Learning
#
# Row 16704: Predicted -> Matrix
#
# Row 16701: Predicted -> Machine Learning
#
# Row 16705: Predicted -> Sorting
#
# Row 16703: Predicted -> Sorting
# Processed 16705/18612 rows so far
#
# Row 16709: Predicted -> Web Dev
#
# Row 16707: Predicted -> tree
#
# Row 16708: Predicted -> string
#
# Row 16706: Predicted -> Tree
#
# Row 16710: Predicted -> Tree
# Processed 16710/18612 rows so far
#
# Row 16715: Predicted -> Array
#
# Row 16711: Predicted -> Sorting
#
# Row 16712: Predicted -> String
#
# Row 16714: Predicted -> searching
#
# Row 16713: Predicted -> Mathematical Calculation
# Processed 16715/18612 rows so far
#
# Row 16719: Predicted -> string
#
# Row 16720: Predicted -> Machine Learning
#
# Row 16717: Predicted -> Database
#
# Row 16716: Predicted -> tree
#
# Row 16718: Predicted -> Web Dev
# Processed 16720/18612 rows so far
#
# Row 16722: Predicted -> Encryption
#
# Row 16721: Predicted -> Web Dev
#
# Row 16725: Predicted -> Sorting
#
# Row 16723: Predicted -> Nouns
#
# Row 16724: Predicted -> Set
# Processed 16725/18612 rows so far
#
# Row 16727: Predicted -> Sorting
#
# Row 16726: Predicted -> Sorting
#
# Row 16730: Predicted -> Sorting
#
# Row 16729: Predicted -> Web Dev
#
# Row 16728: Predicted -> string
# Processed 16730/18612 rows so far
#
# Row 16731: Predicted -> string
#
# Row 16735: Predicted -> Sorting
#
# Row 16733: Predicted -> Data Analysis
#
# Row 16732: Predicted -> searching
#
# Row 16734: Predicted -> Sorting
# Processed 16735/18612 rows so far
#
# Row 16740: Predicted -> Array
#
# Row 16739: Predicted -> searching
#
# Row 16738: Predicted -> Linked List
#
# Row 16737: Predicted -> Tree
#
# Row 16736: Predicted -> Sorting
# Processed 16740/18612 rows so far
#
# Row 16745: Predicted -> Sorting
#
# Row 16743: Predicted -> Machine Learning
#
# Row 16742: Predicted -> Array
#
# Row 16741: Predicted -> Web Dev
#
# Row 16744: Predicted -> String
# Processed 16745/18612 rows so far
#
# Row 16747: Predicted -> searching
#
# Row 16749: Predicted -> string
#
# Row 16746: Predicted -> tree
#
# Row 16748: Predicted -> Graph
#
# Row 16750: Predicted -> Tree
# Processed 16750/18612 rows so far
#
# Row 16755: Predicted -> Sorting
#
# Row 16752: Predicted -> Tree
#
# Row 16754: Predicted -> Web Dev
#
# Row 16751: Predicted -> Text Generation
#
# Row 16753: Predicted -> Number Theory
# Processed 16755/18612 rows so far
#
# Row 16759: Predicted -> Sorting
#
# Row 16757: Predicted -> graph
#
# Row 16756: Predicted -> String
#
# Row 16760: Predicted -> String
#
# Row 16758: Predicted -> Number Theory
# Processed 16760/18612 rows so far
#
# Row 16761: Predicted -> dictionary
#
# Row 16764: Predicted -> Book
#
# Row 16765: Predicted -> Tree
#
# Row 16762: Predicted -> string
#
# Row 16763: Predicted -> Web Dev
# Processed 16765/18612 rows so far
#
# Row 16770: Predicted -> Code
#
# Row 16769: Predicted -> Machine Learning
#
# Row 16767: Predicted -> Web Dev
#
# Row 16766: Predicted -> searching
#
# Row 16768: Predicted -> Sorting
# Processed 16770/18612 rows so far
#
# Row 16775: Predicted -> Sorting
#
# Row 16771: Predicted -> searching
#
# Row 16772: Predicted -> Machine Learning
#
# Row 16773: Predicted -> Classification: Object-Oriented Programming (OOP)
#
# Row 16774: Predicted -> Array
# Processed 16775/18612 rows so far
#
# Row 16776: Predicted -> string
#
# Row 16779: Predicted -> string
#
# Row 16780: Predicted -> Sorting
#
# Row 16778: Predicted -> Sorting
#
# Row 16777: Predicted -> Sorting
# Processed 16780/18612 rows so far
#
# Row 16785: Predicted -> string
#
# Row 16783: Predicted -> Optimization
#
# Row 16784: Predicted -> Array
#
# Row 16781: Predicted -> Machine Learning
#
# Row 16782: Predicted -> Sorting
# Processed 16785/18612 rows so far
#
# Row 16788: Predicted -> Machine Learning
#
# Row 16787: Predicted -> Sorting
#
# Row 16786: Predicted -> Web Dev
#
# Row 16789: Predicted -> Tree
#
# Row 16790: Predicted -> Sorting
# Processed 16790/18612 rows so far
#
# Row 16793: Predicted -> Sorting
#
# Row 16794: Predicted -> string
#
# Row 16792: Predicted -> Sorting
#
# Row 16791: Predicted -> Tree
#
# Row 16795: Predicted -> Machine Learning
# Processed 16795/18612 rows so far
#
# Row 16800: Predicted -> Sorting
#
# Row 16797: Predicted -> Web Dev
#
# Row 16799: Predicted -> Sorting
#
# Row 16796: Predicted -> Encryption
#
# Row 16798: Predicted -> String
# Processed 16800/18612 rows so far
#
# Row 16802: Predicted -> Sorting
#
# Row 16801: Predicted -> Tree
#
# Row 16803: Predicted -> Geocoding
#
# Row 16804: Predicted -> Sorting
#
# Row 16805: Predicted -> Sorting
# Processed 16805/18612 rows so far
#
# Row 16807: Predicted -> String
#
# Row 16806: Predicted -> Tree
#
# Row 16808: Predicted -> Sorting
#
# Row 16809: Predicted -> Array
#
# Row 16810: Predicted -> Web Dev
# Processed 16810/18612 rows so far
#
# Row 16811: Predicted -> Array
#
# Row 16815: Predicted -> Sorting
#
# Row 16814: Predicted -> Category: Clustering
#
# Row 16812: Predicted -> searching
#
# Row 16813: Predicted -> Sorting
# Processed 16815/18612 rows so far
#
# Row 16817: Predicted -> Sorting
#
# Row 16818: Predicted -> Sorting
#
# Row 16816: Predicted -> Sorting
#
# Row 16820: Predicted -> Sorting
#
# Row 16819: Predicted -> string
# Processed 16820/18612 rows so far
#
# Row 16821: Predicted -> Game Development
#
# Row 16825: Predicted -> string
#
# Row 16822: Predicted -> string
#
# Row 16824: Predicted -> math
#
# Row 16823: Predicted -> Machine Learning
# Processed 16825/18612 rows so far
#
# Row 16827: Predicted -> Sorting
#
# Row 16830: Predicted -> Stack
#
# Row 16826: Predicted -> Sorting
#
# Row 16829: Predicted -> Dictionary
#
# Row 16828: Predicted -> Sorting
# Processed 16830/18612 rows so far
#
# Row 16832: Predicted -> String
#
# Row 16835: Predicted -> Tree
#
# Row 16833: Predicted -> Sorting
#
# Row 16831: Predicted -> string
#
# Row 16834: Predicted -> Sentiment Analysis
# Processed 16835/18612 rows so far
#
# Row 16840: Predicted -> Sorting
#
# Row 16836: Predicted -> string
#
# Row 16837: Predicted -> Machine Learning
#
# Row 16839: Predicted -> Classification: Object-Oriented Programming (OOP)
#
# Row 16838: Predicted -> Database
# Processed 16840/18612 rows so far
#
# Row 16841: Predicted -> Bank Account
#
# Row 16842: Predicted -> Device Management
#
# Row 16845: Predicted -> Sorting
#
# Row 16843: Predicted -> Sorting
#
# Row 16844: Predicted -> Sorting
# Processed 16845/18612 rows so far
#
# Row 16847: Predicted -> Mathematical Calculation
#
# Row 16848: Predicted -> Tree
#
# Row 16849: Predicted -> Dictionary
#
# Row 16850: Predicted -> Sorting
#
# Row 16846: Predicted -> Web Dev
# Processed 16850/18612 rows so far
#
# Row 16852: Predicted -> String
#
# Row 16853: Predicted -> Sorting
#
# Row 16855: Predicted -> Dataframe
#
# Row 16854: Predicted -> Sorting
#
# Row 16851: Predicted -> Dictionary
# Processed 16855/18612 rows so far
#
# Row 16859: Predicted -> Sorting
#
# Row 16858: Predicted -> Machine Learning
#
# Row 16856: Predicted -> Sorting
#
# Row 16860: Predicted -> Sorting
#
# Row 16857: Predicted -> string
# Processed 16860/18612 rows so far
#
# Row 16862: Predicted -> Mathematical Calculation
#
# Row 16863: Predicted -> String
#
# Row 16861: Predicted -> Web Dev
#
# Row 16864: Predicted -> Sorting
#
# Row 16865: Predicted -> Tree
# Processed 16865/18612 rows so far
#
# Row 16867: Predicted -> Sorting
#
# Row 16866: Predicted -> tree
#
# Row 16869: Predicted -> Singleton
#
# Row 16868: Predicted -> Number Theory
#
# Row 16870: Predicted -> Date and Time
# Processed 16870/18612 rows so far
#
# Row 16872: Predicted -> Sorting
#
# Row 16874: Predicted -> Web Dev
#
# Row 16873: Predicted -> Array
#
# Row 16875: Predicted -> Sorting
#
# Row 16871: Predicted -> Machine Learning
# Processed 16875/18612 rows so far
#
# Row 16878: Predicted -> Sorting
#
# Row 16877: Predicted -> Sorting
#
# Row 16876: Predicted -> string
#
# Row 16879: Predicted -> Queue
#
# Row 16880: Predicted -> string
# Processed 16880/18612 rows so far
#
# Row 16882: Predicted -> Sorting
#
# Row 16884: Predicted -> Sorting
#
# Row 16883: Predicted -> string
#
# Row 16885: Predicted -> Array
#
# Row 16881: Predicted -> Tree
# Processed 16885/18612 rows so far
#
# Row 16887: Predicted -> Database
#
# Row 16890: Predicted -> Mathematical Calculation
#
# Row 16889: Predicted -> Machine Learning
#
# Row 16886: Predicted -> Sorting
#
# Row 16888: Predicted -> Sorting
# Processed 16890/18612 rows so far
#
# Row 16892: Predicted -> Machine Learning
#
# Row 16894: Predicted -> Tree
#
# Row 16891: Predicted -> Array
#
# Row 16893: Predicted -> Web Dev
#
# Row 16895: Predicted -> Sorting
# Processed 16895/18612 rows so far
#
# Row 16898: Predicted -> Sorting
#
# Row 16899: Predicted -> Function
#
# Row 16897: Predicted -> Classification: Object Oriented Python Program
#
# Row 16900: Predicted -> Environment
#
# Row 16896: Predicted -> searching
# Processed 16900/18612 rows so far
#
# Row 16905: Predicted -> Sorting
#
# Row 16904: Predicted -> String
#
# Row 16902: Predicted -> Machine Learning
#
# Row 16903: Predicted -> Classification
#
# Row 16901: Predicted -> Sorting
# Processed 16905/18612 rows so far
#
# Row 16908: Predicted -> string
#
# Row 16907: Predicted -> Web Dev
#
# Row 16906: Predicted -> graph
#
# Row 16909: Predicted -> Machine Learning
#
# Row 16910: Predicted -> tree
# Processed 16910/18612 rows so far
#
# Row 16914: Predicted -> Machine Learning
#
# Row 16913: Predicted -> Text Analysis
#
# Row 16912: Predicted -> Web Dev
#
# Row 16915: Predicted -> Sorting
#
# Row 16911: Predicted -> Category: Text Classification
# Processed 16915/18612 rows so far
#
# Row 16917: Predicted -> Sorting
#
# Row 16919: Predicted -> Sorting
#
# Row 16918: Predicted -> Sorting
#
# Row 16920: Predicted -> Sorting
#
# Row 16916: Predicted -> UUID
# Processed 16920/18612 rows so far
#
# Row 16925: Predicted -> Sorting
#
# Row 16924: Predicted -> Math Operations
#
# Row 16923: Predicted -> Sorting
#
# Row 16922: Predicted -> Machine Learning
#
# Row 16921: Predicted -> Sorting
# Processed 16925/18612 rows so far
#
# Row 16926: Predicted -> Graph
#
# Row 16927: Predicted -> string
#
# Row 16928: Predicted -> graph
#
# Row 16929: Predicted -> Sorting
#
# Row 16930: Predicted -> Sorting
# Processed 16930/18612 rows so far
#
# Row 16932: Predicted -> Array
#
# Row 16931: Predicted -> Sorting
#
# Row 16935: Predicted -> Dictionary
#
# Row 16934: Predicted -> Sorting
#
# Row 16933: Predicted -> Application
# Processed 16935/18612 rows so far
#
# Row 16940: Predicted -> Web Dev
#
# Row 16937: Predicted -> Dictionary
#
# Row 16939: Predicted -> hashmap
#
# Row 16938: Predicted -> Sorting
#
# Row 16936: Predicted -> Classification
# Processed 16940/18612 rows so far
#
# Row 16945: Predicted -> searching
#
# Row 16944: Predicted -> Sorting
#
# Row 16943: Predicted -> Geometry
#
# Row 16942: Predicted -> Sorting
#
# Row 16941: Predicted -> Mathematical Calculation
# Processed 16945/18612 rows so far
#
# Row 16946: Predicted -> Sorting
#
# Row 16947: Predicted -> Sorting
#
# Row 16948: Predicted -> Sorting
#
# Row 16949: Predicted -> Sorting
#
# Row 16950: Predicted -> Mathematical Calculation
# Processed 16950/18612 rows so far
#
# Row 16955: Predicted -> hashmap
#
# Row 16951: Predicted -> Sorting
#
# Row 16954: Predicted -> Clustering
#
# Row 16952: Predicted -> string
#
# Row 16953: Predicted -> Mathematical Calculation
# Processed 16955/18612 rows so far
#
# Row 16957: Predicted -> Machine Learning
#
# Row 16956: Predicted -> Tree
#
# Row 16959: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 16960: Predicted -> Mathematical Calculation
#
# Row 16958: Predicted -> Date Checker
# Processed 16960/18612 rows so far
#
# Row 16964: Predicted -> Sorting
#
# Row 16963: Predicted -> Sorting
#
# Row 16962: Predicted -> Mathematical Calculation
#
# Row 16965: Predicted -> string
#
# Row 16961: Predicted -> Web Dev
# Processed 16965/18612 rows so far
#
# Row 16966: Predicted -> Sorting
#
# Row 16969: Predicted -> Web Dev
#
# Row 16968: Predicted -> tree
#
# Row 16967: Predicted -> Sorting
#
# Row 16970: Predicted -> Sorting
# Processed 16970/18612 rows so far
#
# Row 16972: Predicted -> tree
#
# Row 16973: Predicted -> string
#
# Row 16971: Predicted -> string
#
# Row 16974: Predicted -> Sorting
#
# Row 16975: Predicted -> Sorting
# Processed 16975/18612 rows so far
#
# Row 16977: Predicted -> Sorting
#
# Row 16979: Predicted -> Sorting
#
# Row 16976: Predicted -> Sorting
#
# Row 16980: Predicted -> string
#
# Row 16978: Predicted -> graph
# Processed 16980/18612 rows so far
#
# Row 16984: Predicted -> Sorting
#
# Row 16985: Predicted -> Tree
#
# Row 16982: Predicted -> Table Data
#
# Row 16981: Predicted -> Data Structure
#
# Row 16983: Predicted -> Sorting
# Processed 16985/18612 rows so far
#
# Row 16988: Predicted -> hashmap
#
# Row 16990: Predicted -> Web Dev
#
# Row 16989: Predicted -> Sorting
#
# Row 16986: Predicted -> Sorting
#
# Row 16987: Predicted -> math
# Processed 16990/18612 rows so far
#
# Row 16992: Predicted -> Mathematical Calculation
#
# Row 16991: Predicted -> Sorting
#
# Row 16993: Predicted -> Graph
#
# Row 16995: Predicted -> Sorting
#
# Row 16994: Predicted -> Sorting
# Processed 16995/18612 rows so far
#
# Row 16996: Predicted -> string
#
# Row 16999: Predicted -> Tree
#
# Row 16998: Predicted -> Sorting
#
# Row 16997: Predicted -> Sorting
#
# Row 17000: Predicted -> Web Dev
# Processed 17000/18612 rows so far
#
# Row 17004: Predicted -> Tree
#
# Row 17002: Predicted -> Sorting
#
# Row 17003: Predicted -> Tree
#
# Row 17005: Predicted -> Machine Learning
#
# Row 17001: Predicted -> searching
# Processed 17005/18612 rows so far
#
# Row 17008: Predicted -> game
#
# Row 17010: Predicted -> Sorting
#
# Row 17009: Predicted -> Sorting
#
# Row 17007: Predicted -> Sorting
#
# Row 17006: Predicted -> Web Dev
# Processed 17010/18612 rows so far
#
# Row 17013: Predicted -> Sorting
#
# Row 17011: Predicted -> Sorting
#
# Row 17012: Predicted -> Sorting
#
# Row 17014: Predicted -> Sorting
#
# Row 17015: Predicted -> Data Analysis
# Processed 17015/18612 rows so far
#
# Row 17016: Predicted -> math
#
# Row 17017: Predicted -> Sorting
#
# Row 17018: Predicted -> Machine Learning
#
# Row 17020: Predicted -> Sorting
#
# Row 17019: Predicted -> String
# Processed 17020/18612 rows so far
#
# Row 17021: Predicted -> Web Dev
#
# Row 17022: Predicted -> Sorting
#
# Row 17025: Predicted -> tree
#
# Row 17023: Predicted -> Machine Learning
#
# Row 17024: Predicted -> tree
# Processed 17025/18612 rows so far
#
# Row 17029: Predicted -> Sorting
#
# Row 17027: Predicted -> Sorting
#
# Row 17026: Predicted -> Sorting
#
# Row 17028: Predicted -> Tree
#
# Row 17030: Predicted -> Mathematical Operations
# Processed 17030/18612 rows so far
#
# Row 17032: Predicted -> Sorting
#
# Row 17031: Predicted -> String
#
# Row 17035: Predicted -> Vector
#
# Row 17033: Predicted -> Web Dev
#
# Row 17034: Predicted -> Dictionary
# Processed 17035/18612 rows so far
#
# Row 17036: Predicted -> searching
#
# Row 17038: Predicted -> Sorting
#
# Row 17040: Predicted -> Graph
#
# Row 17037: Predicted -> Sorting
#
# Row 17039: Predicted -> Array
# Processed 17040/18612 rows so far
#
# Row 17042: Predicted -> Sentiment Analysis
#
# Row 17041: Predicted -> Sorting
#
# Row 17044: Predicted -> Web Dev
#
# Row 17045: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 17043: Predicted -> Sorting
# Processed 17045/18612 rows so far
#
# Row 17046: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 17050: Predicted -> Tree
#
# Row 17047: Predicted -> Sorting
#
# Row 17049: Predicted -> Sorting
#
# Row 17048: Predicted -> Dictionary
# Processed 17050/18612 rows so far
#
# Row 17054: Predicted -> Sorting
#
# Row 17055: Predicted -> Sorting
#
# Row 17053: Predicted -> Sorting
#
# Row 17052: Predicted -> Sorting
#
# Row 17051: Predicted -> Sorting
# Processed 17055/18612 rows so far
#
# Row 17058: Predicted -> geometry
#
# Row 17057: Predicted -> Sorting
#
# Row 17059: Predicted -> Sorting
#
# Row 17056: Predicted -> Clustering
#
# Row 17060: Predicted -> NLP
# Processed 17060/18612 rows so far
#
# Row 17065: Predicted -> Graph
#
# Row 17061: Predicted -> searching
#
# Row 17064: Predicted -> searching
#
# Row 17063: Predicted -> Sorting
#
# Row 17062: Predicted -> string
# Processed 17065/18612 rows so far
#
# Row 17068: Predicted -> Data Structure
#
# Row 17069: Predicted -> string
#
# Row 17070: Predicted -> Array
#
# Row 17066: Predicted -> Sorting
#
# Row 17067: Predicted -> Sorting
# Processed 17070/18612 rows so far
#
# Row 17073: Predicted -> Sorting
#
# Row 17074: Predicted -> Tree
#
# Row 17072: Predicted -> string
#
# Row 17071: Predicted -> Machine Learning
#
# Row 17075: Predicted -> Sorting
# Processed 17075/18612 rows so far
#
# Row 17080: Predicted -> Text Classification
#
# Row 17079: Predicted -> Dictionary
#
# Row 17076: Predicted -> Dictionary
#
# Row 17077: Predicted -> string
#
# Row 17078: Predicted -> searching
# Processed 17080/18612 rows so far
#
# Row 17084: Predicted -> Web Dev
#
# Row 17083: Predicted -> Sorting
#
# Row 17081: Predicted -> Tree
#
# Row 17082: Predicted -> Sorting
#
# Row 17085: Predicted -> Database
# Processed 17085/18612 rows so far
#
# Row 17086: Predicted -> Sorting
#
# Row 17089: Predicted -> Dictionary
#
# Row 17090: Predicted -> Web Dev
#
# Row 17088: Predicted -> Mathematical Operations
#
# Row 17087: Predicted -> Matrix
# Processed 17090/18612 rows so far
#
# Row 17094: Predicted -> Sorting
#
# Row 17091: Predicted -> Web Dev
#
# Row 17095: Predicted -> Dictionary
#
# Row 17093: Predicted -> Web Dev
#
# Row 17092: Predicted -> string
# Processed 17095/18612 rows so far
#
# Row 17100: Predicted -> Web Dev
#
# Row 17099: Predicted -> string
#
# Row 17096: Predicted -> string
#
# Row 17097: Predicted -> Sorting
#
# Row 17098: Predicted -> string
# Processed 17100/18612 rows so far
#
# Row 17103: Predicted -> Sorting
#
# Row 17104: Predicted -> Date
#
# Row 17101: Predicted -> Sorting
#
# Row 17105: Predicted -> Sorting
#
# Row 17102: Predicted -> Web Dev
# Processed 17105/18612 rows so far
#
# Row 17106: Predicted -> Sorting
#
# Row 17109: Predicted -> Mathematical Operations
#
# Row 17110: Predicted -> Sorting
#
# Row 17108: Predicted -> Sorting
#
# Row 17107: Predicted -> tree
# Processed 17110/18612 rows so far
#
# Row 17113: Predicted -> Machine Learning
#
# Row 17115: Predicted -> Sorting
#
# Row 17114: Predicted -> Sorting
#
# Row 17112: Predicted -> Sorting
#
# Row 17111: Predicted -> Array
# Processed 17115/18612 rows so far
#
# Row 17117: Predicted -> Web Dev
#
# Row 17116: Predicted -> Sorting
#
# Row 17119: Predicted -> Chatbot
#
# Row 17120: Predicted -> Sorting
#
# Row 17118: Predicted -> tree
# Processed 17120/18612 rows so far
#
# Row 17124: Predicted -> string
#
# Row 17123: Predicted -> Sorting
#
# Row 17121: Predicted -> Web Dev
#
# Row 17122: Predicted -> Sorting
#
# Row 17125: Predicted -> Sorting
# Processed 17125/18612 rows so far
#
# Row 17130: Predicted -> tree
#
# Row 17127: Predicted -> Questionnaire
#
# Row 17129: Predicted -> string
#
# Row 17126: Predicted -> Data Analysis
#
# Row 17128: Predicted -> Sorting
# Processed 17130/18612 rows so far
#
# Row 17135: Predicted -> tree
#
# Row 17134: Predicted -> Sorting
#
# Row 17131: Predicted -> Compression
#
# Row 17132: Predicted -> Sorting
#
# Row 17133: Predicted -> Sorting
# Processed 17135/18612 rows so far
#
# Row 17136: Predicted -> Machine Learning
#
# Row 17138: Predicted -> File System Manipulation
#
# Row 17140: Predicted -> Sorting
#
# Row 17139: Predicted -> string
#
# Row 17137: Predicted -> Chatbot
# Processed 17140/18612 rows so far
#
# Row 17141: Predicted -> Sorting
#
# Row 17142: Predicted -> Graph
#
# Row 17144: Predicted -> Mathematical Operations
#
# Row 17143: Predicted -> tree
#
# Row 17145: Predicted -> Sorting
# Processed 17145/18612 rows so far
#
# Row 17148: Predicted -> String Matching
#
# Row 17147: Predicted -> Sorting
#
# Row 17150: Predicted -> Category: String
#
# Row 17146: Predicted -> Data Structure
#
# Row 17149: Predicted -> Tree
# Processed 17150/18612 rows so far
#
# Row 17151: Predicted -> String
#
# Row 17154: Predicted -> Data Processing and Analysis
#
# Row 17153: Predicted -> Number
#
# Row 17155: Predicted -> Sorting
#
# Row 17152: Predicted -> Mathematical Calculation
# Processed 17155/18612 rows so far
#
# Row 17156: Predicted -> Sorting
#
# Row 17157: Predicted -> Mathematical Calculation
#
# Row 17159: Predicted -> Sorting
#
# Row 17158: Predicted -> Sorting
#
# Row 17160: Predicted -> Dictionary
# Processed 17160/18612 rows so far
#
# Row 17163: Predicted -> Clustering
#
# Row 17165: Predicted -> searching
#
# Row 17162: Predicted -> string
#
# Row 17161: Predicted -> Web Dev
#
# Row 17164: Predicted -> Text Processing
# Processed 17165/18612 rows so far
#
# Row 17169: Predicted -> Array
#
# Row 17167: Predicted -> Sorting
#
# Row 17166: Predicted -> searching
#
# Row 17168: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 17170: Predicted -> Mathematical Calculation
# Processed 17170/18612 rows so far
#
# Row 17172: Predicted -> Sorting
#
# Row 17171: Predicted -> Sorting
#
# Row 17174: Predicted -> Graph
#
# Row 17173: Predicted -> Sorting
#
# Row 17175: Predicted -> Heap
# Processed 17175/18612 rows so far
#
# Row 17179: Predicted -> Tree
#
# Row 17176: Predicted -> Game
#
# Row 17177: Predicted -> Graph
#
# Row 17178: Predicted -> Machine Learning
#
# Row 17180: Predicted -> Sorting
# Processed 17180/18612 rows so far
#
# Row 17185: Predicted -> Machine Learning
#
# Row 17183: Predicted -> Sorting
#
# Row 17182: Predicted -> Machine Learning
#
# Row 17184: Predicted -> Web Dev
#
# Row 17181: Predicted -> string
# Processed 17185/18612 rows so far
#
# Row 17187: Predicted -> statistics
#
# Row 17189: Predicted -> Web Dev
#
# Row 17186: Predicted -> Tree
#
# Row 17190: Predicted -> Dictionary
#
# Row 17188: Predicted -> Sorting
# Processed 17190/18612 rows so far
#
# Row 17191: Predicted -> hashmap
#
# Row 17193: Predicted -> Sorting
#
# Row 17192: Predicted -> Sorting
#
# Row 17195: Predicted -> Mathematical Calculation
#
# Row 17194: Predicted -> Category: Sorting
# Processed 17195/18612 rows so far
#
# Row 17197: Predicted -> Sorting
#
# Row 17199: Predicted -> Sorting
#
# Row 17198: Predicted -> Sorting
#
# Row 17200: Predicted -> Web Dev
#
# Row 17196: Predicted -> Sorting
# Processed 17200/18612 rows so far
#
# Row 17205: Predicted -> Sorting
#
# Row 17201: Predicted -> Sentiment Analysis
#
# Row 17203: Predicted -> Sorting
#
# Row 17202: Predicted -> Machine Learning
#
# Row 17204: Predicted -> Number Generation
# Processed 17205/18612 rows so far
#
# Row 17207: Predicted -> searching
#
# Row 17208: Predicted -> Sorting
#
# Row 17210: Predicted -> tree
#
# Row 17209: Predicted -> Sorting
#
# Row 17206: Predicted -> Sorting
# Processed 17210/18612 rows so far
#
# Row 17212: Predicted -> String
#
# Row 17211: Predicted -> Machine Learning
#
# Row 17213: Predicted -> Machine Learning
#
# Row 17214: Predicted -> Sorting
#
# Row 17215: Predicted -> Array
# Processed 17215/18612 rows so far
#
# Row 17219: Predicted -> Tree
#
# Row 17218: Predicted -> Sorting
#
# Row 17216: Predicted -> Sorting
#
# Row 17217: Predicted -> String
#
# Row 17220: Predicted -> Classification: Object-Oriented Programming (OOP)
# Processed 17220/18612 rows so far
#
# Row 17222: Predicted -> Sorting
#
# Row 17221: Predicted -> Random Number Generation
#
# Row 17224: Predicted -> math
#
# Row 17223: Predicted -> searching
#
# Row 17225: Predicted -> Mathematical Calculation
# Processed 17225/18612 rows so far
#
# Row 17227: Predicted -> Mathematical Operations
#
# Row 17228: Predicted -> Array
#
# Row 17229: Predicted -> Sorting
#
# Row 17230: Predicted -> string
#
# Row 17226: Predicted -> Sorting
# Processed 17230/18612 rows so far
#
# Row 17231: Predicted -> Sorting
#
# Row 17234: Predicted -> Number Theory
#
# Row 17233: Predicted -> Sorting
#
# Row 17235: Predicted -> Mathematical Calculation
#
# Row 17232: Predicted -> Web Dev
# Processed 17235/18612 rows so far
#
# Row 17238: Predicted -> Sorting
#
# Row 17236: Predicted -> Web Dev
#
# Row 17239: Predicted -> Sorting
#
# Row 17240: Predicted -> Machine Learning
#
# Row 17237: Predicted -> String
# Processed 17240/18612 rows so far
#
# Row 17243: Predicted -> Optimization
#
# Row 17241: Predicted -> Array
#
# Row 17245: Predicted -> String
#
# Row 17242: Predicted -> Sorting
#
# Row 17244: Predicted -> Sorting
# Processed 17245/18612 rows so far
#
# Row 17249: Predicted -> Array
#
# Row 17248: Predicted -> Sorting
#
# Row 17246: Predicted -> Web Dev
#
# Row 17247: Predicted -> Sorting
#
# Row 17250: Predicted -> Sorting
# Processed 17250/18612 rows so far
#
# Row 17255: Predicted -> Game
#
# Row 17251: Predicted -> Sorting
#
# Row 17253: Predicted -> Machine Learning
#
# Row 17254: Predicted -> Tree
#
# Row 17252: Predicted -> Database
# Processed 17255/18612 rows so far
#
# Row 17257: Predicted -> Tree
#
# Row 17256: Predicted -> Tree
#
# Row 17259: Predicted -> Sorting
#
# Row 17260: Predicted -> Tree
#
# Row 17258: Predicted -> Web Dev
# Processed 17260/18612 rows so far
#
# Row 17264: Predicted -> Sorting
#
# Row 17265: Predicted -> Web Dev
#
# Row 17261: Predicted -> Number Theory
#
# Row 17262: Predicted -> string
#
# Row 17263: Predicted -> Sorting
# Processed 17265/18612 rows so far
#
# Row 17267: Predicted -> Sorting
#
# Row 17270: Predicted -> Sorting
#
# Row 17266: Predicted -> string
#
# Row 17269: Predicted -> Hashmap
#
# Row 17268: Predicted -> math
# Processed 17270/18612 rows so far
#
# Row 17271: Predicted -> Sorting
#
# Row 17274: Predicted -> Tree
#
# Row 17275: Predicted -> Sorting
#
# Row 17273: Predicted -> Dictionary
#
# Row 17272: Predicted -> Text Processing
# Processed 17275/18612 rows so far
#
# Row 17279: Predicted -> string
#
# Row 17278: Predicted -> File Transfer
#
# Row 17277: Predicted -> Time Measurement
#
# Row 17276: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 17280: Predicted -> Sentiment Analysis
# Processed 17280/18612 rows so far
#
# Row 17281: Predicted -> Array
#
# Row 17282: Predicted -> Model Management
#
# Row 17284: Predicted -> Database Query
#
# Row 17283: Predicted -> Web Dev
#
# Row 17285: Predicted -> Tree
# Processed 17285/18612 rows so far
#
# Row 17287: Predicted -> string
#
# Row 17288: Predicted -> Number
#
# Row 17286: Predicted -> Encryption
#
# Row 17289: Predicted -> hashmap
#
# Row 17290: Predicted -> Sorting
# Processed 17290/18612 rows so far
#
# Row 17295: Predicted -> string
#
# Row 17291: Predicted -> Array
#
# Row 17292: Predicted -> string
#
# Row 17294: Predicted -> Sorting
#
# Row 17293: Predicted -> Sorting
# Processed 17295/18612 rows so far
#
# Row 17297: Predicted -> Sorting
#
# Row 17298: Predicted -> Sorting
#
# Row 17296: Predicted -> Sorting
#
# Row 17300: Predicted -> Mathematical Expression
#
# Row 17299: Predicted -> Classify into: [object]
# Processed 17300/18612 rows so far
#
# Row 17302: Predicted -> Sorting
#
# Row 17305: Predicted -> Sorting
#
# Row 17303: Predicted -> Sorting
#
# Row 17304: Predicted -> Tree
#
# Row 17301: Predicted -> constant
# Processed 17305/18612 rows so far
#
# Row 17309: Predicted -> Web Dev
#
# Row 17306: Predicted -> Graph
#
# Row 17307: Predicted -> math
#
# Row 17310: Predicted -> Sorting
#
# Row 17308: Predicted -> searching
# Processed 17310/18612 rows so far
#
# Row 17315: Predicted -> Machine Learning
#
# Row 17314: Predicted -> Sorting
#
# Row 17313: Predicted -> string
#
# Row 17312: Predicted -> String
#
# Row 17311: Predicted -> Machine Learning
# Processed 17315/18612 rows so far
#
# Row 17316: Predicted -> math
#
# Row 17319: Predicted -> Array
#
# Row 17320: Predicted -> Sorting
#
# Row 17317: Predicted -> Sorting
#
# Row 17318: Predicted -> Dictionary
# Processed 17320/18612 rows so far
#
# Row 17322: Predicted -> Machine Learning
#
# Row 17324: Predicted -> Dictionary
#
# Row 17323: Predicted -> Sorting
#
# Row 17325: Predicted -> tree
#
# Row 17321: Predicted -> Machine Learning
# Processed 17325/18612 rows so far
#
# Row 17329: Predicted -> Sorting
#
# Row 17330: Predicted -> array
#
# Row 17327: Predicted -> Machine Learning
#
# Row 17328: Predicted -> Web Dev
#
# Row 17326: Predicted -> Sorting
# Processed 17330/18612 rows so far
#
# Row 17331: Predicted -> Sorting
#
# Row 17332: Predicted -> Sorting
#
# Row 17333: Predicted -> Sorting
#
# Row 17335: Predicted -> string
#
# Row 17334: Predicted -> Web Dev
# Processed 17335/18612 rows so far
#
# Row 17338: Predicted -> Array
#
# Row 17336: Predicted -> Category: Dictionary
#
# Row 17340: Predicted -> List comprehension
#
# Row 17337: Predicted -> string
#
# Row 17339: Predicted -> Sorting
# Processed 17340/18612 rows so far
#
# Row 17341: Predicted -> Sentiment Analysis
#
# Row 17344: Predicted -> Array
#
# Row 17343: Predicted -> Number Theory
#
# Row 17342: Predicted -> Tree
#
# Row 17345: Predicted -> Array
# Processed 17345/18612 rows so far
#
# Row 17349: Predicted -> Sorting
#
# Row 17346: Predicted -> Dynamic Programming
#
# Row 17348: Predicted -> Image Processing
#
# Row 17350: Predicted -> Address
#
# Row 17347: Predicted -> Database
# Processed 17350/18612 rows so far
#
# Row 17354: Predicted -> Package Management
#
# Row 17352: Predicted -> Web Dev
#
# Row 17351: Predicted -> Table
#
# Row 17355: Predicted -> Sorting
#
# Row 17353: Predicted -> Tree
# Processed 17355/18612 rows so far
#
# Row 17359: Predicted -> Sorting
#
# Row 17356: Predicted -> Sorting
#
# Row 17357: Predicted -> Sorting
#
# Row 17360: Predicted -> string
#
# Row 17358: Predicted -> Dictionary
# Processed 17360/18612 rows so far
#
# Row 17362: Predicted -> Encryption
#
# Row 17364: Predicted -> Data Analysis
#
# Row 17361: Predicted -> Sorting
#
# Row 17363: Predicted -> Matrix
#
# Row 17365: Predicted -> string
# Processed 17365/18612 rows so far
#
# Row 17366: Predicted -> string
#
# Row 17369: Predicted -> Sorting
#
# Row 17368: Predicted -> Sorting
#
# Row 17370: Predicted -> Web Dev
#
# Row 17367: Predicted -> Sorting
# Processed 17370/18612 rows so far
#
# Row 17372: Predicted -> Sorting
#
# Row 17373: Predicted -> Machine Learning
#
# Row 17375: Predicted -> Sorting
#
# Row 17371: Predicted -> Machine Learning
#
# Row 17374: Predicted -> animals
# Processed 17375/18612 rows so far
#
# Row 17377: Predicted -> Machine Learning
#
# Row 17380: Predicted -> Mathematical Calculation
#
# Row 17378: Predicted -> Computer
#
# Row 17376: Predicted -> Web Dev
#
# Row 17379: Predicted -> Machine Learning
# Processed 17380/18612 rows so far
#
# Row 17385: Predicted -> Mathematical Calculation
#
# Row 17382: Predicted -> Temperature Conversion
#
# Row 17384: Predicted -> Classification: [object]
#
# Row 17383: Predicted -> graph
#
# Row 17381: Predicted -> Geometry
# Processed 17385/18612 rows so far
#
# Row 17389: Predicted -> tree
#
# Row 17387: Predicted -> Machine Learning
#
# Row 17386: Predicted -> array
#
# Row 17388: Predicted -> Movie Review
#
# Row 17390: Predicted -> tree
# Processed 17390/18612 rows so far
#
# Row 17394: Predicted -> Sorting
#
# Row 17395: Predicted -> Number Theory
#
# Row 17392: Predicted -> Mathematical Calculation
#
# Row 17393: Predicted -> Game
#
# Row 17391: Predicted -> Sorting
# Processed 17395/18612 rows so far
#
# Row 17398: Predicted -> Sorting
#
# Row 17397: Predicted -> Sorting
#
# Row 17399: Predicted -> Sorting
#
# Row 17396: Predicted -> Sorting
#
# Row 17400: Predicted -> Sorting
# Processed 17400/18612 rows so far
#
# Row 17401: Predicted -> Mathematical Calculation
#
# Row 17404: Predicted -> Web Dev
#
# Row 17402: Predicted -> Machine Learning
#
# Row 17405: Predicted -> Sorting
#
# Row 17403: Predicted -> Sorting
# Processed 17405/18612 rows so far
#
# Row 17410: Predicted -> Sorting
#
# Row 17406: Predicted -> Sorting
#
# Row 17407: Predicted -> tree
#
# Row 17409: Predicted -> Sorting
#
# Row 17408: Predicted -> String
# Processed 17410/18612 rows so far
#
# Row 17414: Predicted -> Sorting
#
# Row 17415: Predicted -> Array
#
# Row 17412: Predicted -> News
#
# Row 17413: Predicted -> searching
#
# Row 17411: Predicted -> Sorting
# Processed 17415/18612 rows so far
#
# Row 17417: Predicted -> Geolocation
#
# Row 17420: Predicted -> Sorting
#
# Row 17419: Predicted -> searching
#
# Row 17418: Predicted -> Encryption
#
# Row 17416: Predicted -> searching
# Processed 17420/18612 rows so far
#
# Row 17421: Predicted -> Polynomial
#
# Row 17424: Predicted -> tree
#
# Row 17423: Predicted -> tree
#
# Row 17422: Predicted -> Color Conversion
#
# Row 17425: Predicted -> Encoding
# Processed 17425/18612 rows so far
#
# Row 17430: Predicted -> string
#
# Row 17426: Predicted -> Number Theory
#
# Row 17429: Predicted -> Sorting
#
# Row 17428: Predicted -> Mathematical Calculation
#
# Row 17427: Predicted -> Sorting
# Processed 17430/18612 rows so far
#
# Row 17431: Predicted -> Web Dev
#
# Row 17432: Predicted -> Sorting
#
# Row 17434: Predicted -> Sorting
#
# Row 17433: Predicted -> Sorting
#
# Row 17435: Predicted -> Machine Learning
# Processed 17435/18612 rows so far
#
# Row 17438: Predicted -> Classification: Object-Oriented Programming (OOP)
#
# Row 17439: Predicted -> searching
#
# Row 17437: Predicted -> string
#
# Row 17440: Predicted -> Distance Calculation
#
# Row 17436: Predicted -> hashmap
# Processed 17440/18612 rows so far
#
# Row 17441: Predicted -> Database
#
# Row 17443: Predicted -> searching
#
# Row 17442: Predicted -> Machine Learning
#
# Row 17445: Predicted -> string
#
# Row 17444: Predicted -> Sorting
# Processed 17445/18612 rows so far
#
# Row 17450: Predicted -> Web Dev
#
# Row 17449: Predicted -> Sorting
#
# Row 17447: Predicted -> Array
#
# Row 17448: Predicted -> Machine Learning
#
# Row 17446: Predicted -> Sorting
# Processed 17450/18612 rows so far
#
# Row 17452: Predicted -> string
#
# Row 17451: Predicted -> Web Dev
#
# Row 17453: Predicted -> Game AI
#
# Row 17454: Predicted -> Sorting
#
# Row 17455: Predicted -> Lexical Analysis
# Processed 17455/18612 rows so far
#
# Row 17458: Predicted -> Sorting
#
# Row 17457: Predicted -> string
#
# Row 17459: Predicted -> Sorting
#
# Row 17460: Predicted -> Sorting
#
# Row 17456: Predicted -> Tree
# Processed 17460/18612 rows so far
#
# Row 17462: Predicted -> Web Dev
#
# Row 17463: Predicted -> string
#
# Row 17461: Predicted -> Machine Learning
#
# Row 17464: Predicted -> Graph
#
# Row 17465: Predicted -> Sorting
# Processed 17465/18612 rows so far
#
# Row 17466: Predicted -> string
#
# Row 17468: Predicted -> Web Dev
#
# Row 17469: Predicted -> Tree
#
# Row 17470: Predicted -> Sorting
#
# Row 17467: Predicted -> Text Generation
# Processed 17470/18612 rows so far
#
# Row 17471: Predicted -> Temperature Conversion
#
# Row 17475: Predicted -> Sorting
#
# Row 17472: Predicted -> Web Dev
#
# Row 17473: Predicted -> Automation
#
# ...
#
# Row 18274: Predicted -> tree
# Processed 18275/18612 rows so far
#
# Row 18276: Predicted -> hashmap
#
# Row 18277: Predicted -> Health and Fitness
#
# Row 18279: Predicted -> searching
#
# Row 18280: Predicted -> searching
#
# Row 18278: Predicted -> Sorting
# Processed 18280/18612 rows so far
#
# Row 18282: Predicted -> Sorting
#
# Row 18281: Predicted -> Set
#
# Row 18285: Predicted -> Sorting
#
# Row 18284: Predicted -> searching
#
# Row 18283: Predicted -> Sorting
# Processed 18285/18612 rows so far
#
# Row 18287: Predicted -> Sorting
#
# Row 18286: Predicted -> Array
#
# Row 18290: Predicted -> Sorting
#
# Row 18288: Predicted -> Sorting
#
# Row 18289: Predicted -> Clustering
# Processed 18290/18612 rows so far
#
# Row 18291: Predicted -> Sorting
#
# Row 18293: Predicted -> Number Theory
#
# Row 18295: Predicted -> Sorting
#
# Row 18294: Predicted -> Number to Words
#
# Row 18292: Predicted -> Sorting
# Processed 18295/18612 rows so far
#
# Row 18297: Predicted -> String
#
# Row 18298: Predicted -> Number Theory
#
# Row 18299: Predicted -> Array
#
# Row 18300: Predicted -> Sorting
#
# Row 18296: Predicted -> searching
# Processed 18300/18612 rows so far
#
# Row 18303: Predicted -> searching
#
# Row 18302: Predicted -> Language Detection
#
# Row 18301: Predicted -> Sorting
#
# Row 18304: Predicted -> Sorting
#
# Row 18305: Predicted -> Database
# Processed 18305/18612 rows so far
#
# Row 18310: Predicted -> Searching
#
# Row 18309: Predicted -> Tree
#
# Row 18307: Predicted -> array
#
# Row 18308: Predicted -> Machine Learning
#
# Row 18306: Predicted -> Classification
# Processed 18310/18612 rows so far
#
# Row 18315: Predicted -> Sorting
#
# Row 18314: Predicted -> Sorting
#
# Row 18311: Predicted -> Array
#
# Row 18312: Predicted -> Tree
#
# Row 18313: Predicted -> Sorting
# Processed 18315/18612 rows so far
#
# Row 18317: Predicted -> Sorting
#
# Row 18320: Predicted -> Array
#
# Row 18316: Predicted -> Text Mining
#
# Row 18319: Predicted -> Sorting
#
# Row 18318: Predicted -> Sorting
# Processed 18320/18612 rows so far
#
# Row 18321: Predicted -> Sorting
#
# Row 18324: Predicted -> Web Dev
#
# Row 18325: Predicted -> Category: DNS
#
# Row 18323: Predicted -> Category: Design Pattern
#
# Row 18322: Predicted -> Machine Learning
# Processed 18325/18612 rows so far
#
# Row 18328: Predicted -> Classification: Object Oriented Programming (OOP)
#
# Row 18330: Predicted -> Sorting
#
# Row 18329: Predicted -> Dictionary
#
# Row 18327: Predicted -> String
#
# Row 18326: Predicted -> Web Dev
# Processed 18330/18612 rows so far
#
# Row 18331: Predicted -> Sentiment Analysis
#
# Row 18335: Predicted -> Game
#
# Row 18333: Predicted -> Sorting
#
# Row 18332: Predicted -> Sorting
#
# Row 18334: Predicted -> Sorting
# Processed 18335/18612 rows so far
#
# Row 18336: Predicted -> Sorting
#
# Row 18339: Predicted -> string
#
# Row 18338: Predicted -> Tree
#
# Row 18340: Predicted -> Temperature
#
# Row 18337: Predicted -> Sorting
# Processed 18340/18612 rows so far
#
# Row 18341: Predicted -> Sorting
#
# Row 18343: Predicted -> Sorting
#
# Row 18345: Predicted -> string
#
# Row 18342: Predicted -> graph
#
# Row 18344: Predicted -> Machine Learning
# Processed 18345/18612 rows so far
#
# Row 18346: Predicted -> searching
#
# Row 18349: Predicted -> Web Dev
#
# Row 18347: Predicted -> Sorting
#
# Row 18348: Predicted -> Sorting
#
# Row 18350: Predicted -> Sorting
# Processed 18350/18612 rows so far
#
# Row 18352: Predicted -> Category: Sorting
#
# Row 18354: Predicted -> Python
#
# Row 18351: Predicted -> Sorting
#
# Row 18355: Predicted -> Array
#
# Row 18353: Predicted -> Machine Learning
# Processed 18355/18612 rows so far
#
# Row 18357: Predicted -> Dynamic Programming
#
# Row 18360: Predicted -> string
#
# Row 18356: Predicted -> Web Dev
#
# Row 18358: Predicted -> Sorting
#
# Row 18359: Predicted -> Sorting
# Processed 18360/18612 rows so far
#
# Row 18362: Predicted -> Sorting
#
# Row 18361: Predicted -> Web Dev
#
# Row 18364: Predicted -> Tree
#
# Row 18365: Predicted -> Sorting
#
# Row 18363: Predicted -> Table
# Processed 18365/18612 rows so far
#
# Row 18367: Predicted -> Sorting
#
# Row 18368: Predicted -> Graph
#
# Row 18366: Predicted -> string
#
# Row 18370: Predicted -> Text Classification
#
# Row 18369: Predicted -> Cost Calculation
# Processed 18370/18612 rows so far
#
# Row 18371: Predicted -> Category: Searching
#
# Row 18374: Predicted -> Permutation
#
# Row 18373: Predicted -> Web Dev
#
# Row 18372: Predicted -> Sorting
#
# Row 18375: Predicted -> Matrix
# Processed 18375/18612 rows so far
#
# Row 18377: Predicted -> Mathematical Expression
#
# Row 18380: Predicted -> Mathematical Optimization
#
# Row 18379: Predicted -> Sorting
#
# Row 18376: Predicted -> Number Theory
#
# Row 18378: Predicted -> string
# Processed 18380/18612 rows so far
#
# Row 18384: Predicted -> dictionary
#
# Row 18382: Predicted -> Mathematical Calculation
#
# Row 18385: Predicted -> Sorting
#
# Row 18383: Predicted -> Sorting
#
# Row 18381: Predicted -> Sorting
# Processed 18385/18612 rows so far
#
# Row 18390: Predicted -> string
#
# Row 18387: Predicted -> Bank Account
#
# Row 18386: Predicted -> Mathematical Operations
#
# Row 18389: Predicted -> Sorting
#
# Row 18388: Predicted -> tree
# Processed 18390/18612 rows so far
#
# Row 18395: Predicted -> Graph
#
# Row 18392: Predicted -> Sorting
#
# Row 18391: Predicted -> Date Manipulation
#
# Row 18394: Predicted -> graph
#
# Row 18393: Predicted -> Tree
# Processed 18395/18612 rows so far
#
# Row 18400: Predicted -> Sorting
#
# Row 18397: Predicted -> Graph
#
# Row 18396: Predicted -> Mathematical Operations
#
# Row 18399: Predicted -> Sorting
#
# Row 18398: Predicted -> Web Dev
# Processed 18400/18612 rows so far
#
# Row 18403: Predicted -> Mathematical Calculation
#
# Row 18402: Predicted -> Sorting
#
# Row 18401: Predicted -> Sorting
#
# Row 18404: Predicted -> Tree
#
# Row 18405: Predicted -> Tree
# Processed 18405/18612 rows so far
#
# Row 18406: Predicted -> Sorting
#
# Row 18407: Predicted -> Machine Learning
#
# Row 18409: Predicted -> Web Dev
#
# Row 18408: Predicted -> Array
#
# Row 18410: Predicted -> Machine Learning
# Processed 18410/18612 rows so far
#
# Row 18411: Predicted -> Sorting
#
# Row 18414: Predicted -> Sorting
#
# Row 18412: Predicted -> Sorting
#
# Row 18415: Predicted -> searching
#
# Row 18413: Predicted -> Array
# Processed 18415/18612 rows so far
#
# Row 18419: Predicted -> histogram
#
# Row 18416: Predicted -> Sorting
#
# Row 18420: Predicted -> Sorting
#
# Row 18418: Predicted -> Web Dev
#
# Row 18417: Predicted -> Sorting
# Processed 18420/18612 rows so far
#
# Row 18421: Predicted -> Sorting
#
# Row 18422: Predicted -> Machine Learning
#
# Row 18424: Predicted -> Machine Learning
#
# Row 18425: Predicted -> Sorting
#
# Row 18423: Predicted -> Graph
# Processed 18425/18612 rows so far
#
# Row 18427: Predicted -> Neural Network
#
# Row 18428: Predicted -> Sorting
#
# Row 18426: Predicted -> Sorting
#
# Row 18430: Predicted -> array
#
# Row 18429: Predicted -> Sorting
# Processed 18430/18612 rows so far
#
# Row 18434: Predicted -> Mathematical Calculation
#
# Row 18435: Predicted -> Sorting
#
# Row 18433: Predicted -> Machine Learning
#
# Row 18432: Predicted -> Sorting
#
# Row 18431: Predicted -> Machine Learning
# Processed 18435/18612 rows so far
#
# Row 18436: Predicted -> URL
#
# Row 18439: Predicted -> Web Dev
#
# Row 18440: Predicted -> Array
#
# Row 18437: Predicted -> Array
#
# Row 18438: Predicted -> Sorting
# Processed 18440/18612 rows so far
#
# Row 18442: Predicted -> Graph
#
# Row 18443: Predicted -> Sorting
#
# Row 18444: Predicted -> Sorting
#
# Row 18445: Predicted -> Tree
#
# Row 18441: Predicted -> Game
# Processed 18445/18612 rows so far
#
# Row 18449: Predicted -> Number Validation
#
# Row 18450: Predicted -> Sorting
#
# Row 18447: Predicted -> Sorting
#
# Row 18448: Predicted -> Tree
#
# Row 18446: Predicted -> searching
# Processed 18450/18612 rows so far
#
# Row 18454: Predicted -> string
#
# Row 18453: Predicted -> Web Dev
#
# Row 18451: Predicted -> Dynamic Programming
#
# Row 18452: Predicted -> string
#
# Row 18455: Predicted -> Sorting
# Processed 18455/18612 rows so far
#
# Row 18459: Predicted -> Sorting
#
# Row 18456: Predicted -> Sorting
#
# Row 18457: Predicted -> Tree
#
# Row 18460: Predicted -> Tree
#
# Row 18458: Predicted -> Statistics
# Processed 18460/18612 rows so far
#
# Row 18461: Predicted -> Sorting
#
# Row 18465: Predicted -> String
#
# Row 18463: Predicted -> Adventure Game
#
# Row 18462: Predicted -> Sorting
#
# Row 18464: Predicted -> Network Programming
# Processed 18465/18612 rows so far
#
# Row 18469: Predicted -> Sorting
#
# Row 18468: Predicted -> string
#
# Row 18470: Predicted -> Mathematical Calculation
#
# Row 18467: Predicted -> Sorting
#
# Row 18466: Predicted -> set_difference
# Processed 18470/18612 rows so far
#
# Row 18472: Predicted -> Web Dev
#
# Row 18474: Predicted -> Sorting
#
# Row 18471: Predicted -> Mathematical Calculation
#
# Row 18473: Predicted -> searching
#
# Row 18475: Predicted -> Encryption
# Processed 18475/18612 rows so far
#
# Row 18477: Predicted -> Sorting
#
# Row 18479: Predicted -> Sorting
#
# Row 18476: Predicted -> Sorting
#
# Row 18480: Predicted -> Category: Text Analysis
#
# Row 18478: Predicted -> String
# Processed 18480/18612 rows so far
#
# Row 18482: Predicted -> Graph
#
# Row 18483: Predicted -> Sorting
#
# Row 18484: Predicted -> Number Theory
#
# Row 18485: Predicted -> Sorting
#
# Row 18481: Predicted -> Array
# Processed 18485/18612 rows so far
#
# Row 18486: Predicted -> Machine Learning
#
# Row 18487: Predicted -> Sorting
#
# Row 18489: Predicted -> Model
#
# Row 18488: Predicted -> Sorting
#
# Row 18490: Predicted -> Template System
# Processed 18490/18612 rows so far
#
# Row 18495: Predicted -> Machine Learning
#
# Row 18491: Predicted -> List
#
# Row 18493: Predicted -> Sorting
#
# Row 18494: Predicted -> hashmap
#
# Row 18492: Predicted -> Game Theory
# Processed 18495/18612 rows so far
#
# Row 18498: Predicted -> searching
#
# Row 18499: Predicted -> Dictionary
#
# Row 18500: Predicted -> Array
#
# Row 18496: Predicted -> Category: iterable
#
# Row 18497: Predicted -> Array
# Processed 18500/18612 rows so far
#
# Row 18502: Predicted -> Sorting
#
# Row 18504: Predicted -> Sorting
#
# Row 18501: Predicted -> Mathematical Calculation
#
# Row 18503: Predicted -> hashmap
#
# Row 18505: Predicted -> Mathematical Expression
# Processed 18505/18612 rows so far
#
# Row 18506: Predicted -> string
#
# Row 18507: Predicted -> Number Generation
#
# Row 18510: Predicted -> Mathematical Calculation
#
# Row 18509: Predicted -> Mathematical Calculation
#
# Row 18508: Predicted -> Sorting
# Processed 18510/18612 rows so far
#
# Row 18511: Predicted -> Car
#
# Row 18515: Predicted -> Machine Learning
#
# Row 18514: Predicted -> Sorting
#
# Row 18512: Predicted -> Random Number Generation
#
# Row 18513: Predicted -> Sorting
# Processed 18515/18612 rows so far
#
# Row 18520: Predicted -> Sorting
#
# Row 18516: Predicted -> searching
#
# Row 18518: Predicted -> String
#
# Row 18517: Predicted -> Sorting
#
# Row 18519: Predicted -> Dictionary
# Processed 18520/18612 rows so far
#
# Row 18525: Predicted -> Sorting
#
# Row 18524: Predicted -> Sorting
#
# Row 18522: Predicted -> Dictionary
#
# Row 18521: Predicted -> Sorting
#
# Row 18523: Predicted -> string
# Processed 18525/18612 rows so far
#
# Row 18529: Predicted -> Table
#
# Row 18528: Predicted -> Machine Learning
#
# Row 18526: Predicted -> Graph
#
# Row 18530: Predicted -> Machine Learning
#
# Row 18527: Predicted -> Machine Learning
# Processed 18530/18612 rows so far
#
# Row 18534: Predicted -> Web Dev
#
# Row 18532: Predicted -> Sorting
#
# Row 18531: Predicted -> Machine Learning
#
# Row 18535: Predicted -> Sorting
#
# Row 18533: Predicted -> Color Analysis
# Processed 18535/18612 rows so far
#
# Row 18538: Predicted -> Optimization
#
# Row 18537: Predicted -> Array
#
# Row 18539: Predicted -> Web Dev
#
# Row 18540: Predicted -> Sorting
#
# Row 18536: Predicted -> searching
# Processed 18540/18612 rows so far
#
# Row 18541: Predicted -> Graph
#
# Row 18542: Predicted -> Mathematical Calculation
#
# Row 18544: Predicted -> Machine Learning
#
# Row 18545: Predicted -> Matrix
#
# Row 18543: Predicted -> Sentiment Analysis
# Processed 18545/18612 rows so far
#
# Row 18549: Predicted -> Web Dev
#
# Row 18550: Predicted -> Sorting
#
# Row 18547: Predicted -> Sorting
#
# Row 18548: Predicted -> Category: Authentication
#
# Row 18546: Predicted -> Tree
# Processed 18550/18612 rows so far
#
# Row 18552: Predicted -> Sorting
#
# Row 18554: Predicted -> [command line argument parsing]
#
# Row 18551: Predicted -> Matrix
#
# Row 18555: Predicted -> Sorting
#
# Row 18553: Predicted -> Mathematical Calculation
# Processed 18555/18612 rows so far
#
# Row 18560: Predicted -> string
#
# Row 18558: Predicted -> Dictionary
#
# Row 18559: Predicted -> Web Dev
#
# Row 18556: Predicted -> String
#
# Row 18557: Predicted -> Array
# Processed 18560/18612 rows so far
#
# Row 18562: Predicted -> String
#
# Row 18561: Predicted -> string
#
# Row 18564: Predicted -> NLP
#
# Row 18565: Predicted -> string
#
# Row 18563: Predicted -> Graph
# Processed 18565/18612 rows so far
#
# Row 18567: Predicted -> Number Theory
#
# Row 18568: Predicted -> Hashmap
#
# Row 18566: Predicted -> Sorting
#
# Row 18570: Predicted -> Sorting
#
# Row 18569: Predicted -> Mathematical Calculation
# Processed 18570/18612 rows so far
#
# Row 18573: Predicted -> Sorting
#
# Row 18572: Predicted -> Sorting
#
# Row 18574: Predicted -> Sorting
#
# Row 18571: Predicted -> Geometry
#
# Row 18575: Predicted -> Tree
# Processed 18575/18612 rows so far
#
# Row 18579: Predicted -> String
#
# Row 18576: Predicted -> Web Dev
#
# Row 18578: Predicted -> Sorting
#
# Row 18580: Predicted -> Sorting
#
# Row 18577: Predicted -> Tree
# Processed 18580/18612 rows so far
#
# Row 18581: Predicted -> dictionary
#
# Row 18582: Predicted -> Threading
#
# Row 18585: Predicted -> Sorting
#
# Row 18584: Predicted -> Data Structure
#
# Row 18583: Predicted -> tree
# Processed 18585/18612 rows so far
#
# Row 18589: Predicted -> Chatbot
#
# Row 18586: Predicted -> Array
#
# Row 18590: Predicted -> Mathematical Expression Evaluation
#
# Row 18587: Predicted -> Sorting
#
# Row 18588: Predicted -> searching
# Processed 18590/18612 rows so far
#
# Row 18591: Predicted -> Machine Learning
#
# Row 18594: Predicted -> Sorting
#
# Row 18593: Predicted -> Sorting
#
# Row 18595: Predicted -> Number Validation
#
# Row 18592: Predicted -> Mathematical Calculation
# Processed 18595/18612 rows so far
#
# Row 18599: Predicted -> Sorting
#
# Row 18600: Predicted -> Sorting
#
# Row 18596: Predicted -> Sorting
#
# Row 18598: Predicted -> searching
#
# Row 18597: Predicted -> Matrix
# Processed 18600/18612 rows so far
#
# Row 18601: Predicted -> Sorting
#
# Row 18602: Predicted -> Counting Instances
#
# Row 18603: Predicted -> Sorting
#
# Row 18605: Predicted -> Array
#
# Row 18604: Predicted -> Dictionary
# Processed 18605/18612 rows so far
#
# Row 18608: Predicted -> Sorting
#
# Row 18606: Predicted -> Machine Learning
#
# Row 18610: Predicted -> searching
#
# Row 18607: Predicted -> searching
#
# Row 18609: Predicted -> Sorting
# Processed 18610/18612 rows so far
#
# Row 18612: Predicted -> Machine Learning
#
# Row 18611: Predicted -> Web Dev
# Processed 18612/18612 rows so far
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3681987795.py in <cell line: 0>()
#      50 results_dict = dict(final_results)
#      51 df["classification_raw"] = df.index.map(results_dict)
# ---> 52 df[["category", "topic"]] = df["classification_raw"].str.split("|", n=1, expand=True)
#      53 df["category"] = df["category"].str.strip()
#      54 df["topic"] = df["topic"].str.strip()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4339
#    4340             if isinstance(value, DataFrame):
# -> 4341                 check_key_length(self.columns, key, value)
#    4342                 for k1, k2 in zip(key, value.columns):
#    4343                     self[k1] = value[k2]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexers/utils.py in check_key_length(columns, key, value)
#     388     if columns.is_unique:
#     389         if len(value.columns) != len(key):
# --> 390             raise ValueError("Columns must be same length as key")
#     391     else:
#     392         # Missing keys in columns are represented as -1
#
# ValueError: Columns must be same length as key

# %%
# -----------------------------
# SAVE RESULTS
# -----------------------------
results_dict = dict(final_results)

# Each row gets its category directly
df["category"] = df.index.map(results_dict)

# -----------------------------
# SUMMARY
# -----------------------------
print("\nClassification Complete!")
print("\nCategory counts:")
print(df["category"].value_counts())
df.to_csv("alpca_with_category_dataset.xlsx", index=False)

print("\n--- Sample Predictions ---")
for i in range(min(5, len(df))):
    print("\nInstruction:", df.loc[i, "instruction"])
    print("Code:", df.loc[i, "output"][:200], "...")
    print("Predicted Category:", df.loc[i, "category"])
# Out:
# Classification Complete!
#
# Category counts:
# category
# Sorting                 5941
# string                  1339
# Web Dev                 1243
# Machine Learning        1090
# Tree                     942
#                         ...
# Sports                     1
# Text Preprocessing         1
# Category: [sorting]        1
# Performance Analysis       1
# Speech                     1
# Name: count, Length: 711, dtype: int64
#
# --- Sample Predictions ---
#
# Instruction: Create a function to calculate the sum of a sequence of integers.
# Code: # Python code
# def sum_sequence(sequence):
#   sum = 0
#   for num in sequence:
#     sum += num
#   return sum ...
# Predicted Category: Sorting
#
# Instruction: Generate a Python code for crawling a website for a specific type of data.
# Code: import requests
# import re
#
# def crawl_website_for_phone_numbers(website):
#     response = requests.get(website)
#     phone_numbers = re.findall('\d{3}-\d{3}-\d{4}', response.text)
#     return phone_number ...
# Predicted Category: Web Dev
#
# Instruction: Create a Python list comprehension to get the squared values of a list [1, 2, 3, 5, 8, 13].
# Code: [x*x for x in [1, 2, 3, 5, 8, 13]] ...
# Predicted Category: Sorting
#
# Instruction: Generate a python script to perform this action.
# Code: def remove_duplicates(string):
#     result = ""
#     prev = ''
#
#     for char in string:
#         if char != prev:
#             result += char
#             prev = char
#     return result
#
# result = remove ...
# Predicted Category: Sorting
#
# Instruction: Write a python script to generates random numbers between 0 and 9 that are divisible by 3.
# Code: def generate_random_divisible_number():
#     import random
#     while True:
#         # Generate a random number
#         process = random.randint(0, 9)
#         # Check if the number is divisible by 3
#      ...
# Predicted Category: Sorting

# %%
df.head()
# Out:
#    Unnamed: 0                                        instruction  \
# 0           0  Create a function to calculate the sum of a se...
# 1           1  Generate a Python code for crawling a website ...
# 2           2  Create a Python list comprehension to get the ...
# 3           3   Generate a python script to perform this action.
# 4           4  Write a python script to generates random numb...
#
#                                                input  \
# 0                                    [1, 2, 3, 4, 5]
# 1  website: www.example.com \ndata to crawl: phon...
# 2                                                NaN
# 3  Given a string, remove all the consecutive dup...
# 4                                                NaN
#
#                                               output  \
# 0  # Python code\ndef sum_sequence(sequence):\n  ...
# 1  import requests\nimport re\n\ndef crawl_websit...
# 2                 [x*x for x in [1, 2, 3, 5, 8, 13]]
# 3  def remove_duplicates(string): \n    result = ...
# 4  def generate_random_divisible_number():\n    i...
#
#                                               prompt classification_raw  \
# 0  Below is an instruction that describes a task....            Sorting
# 1  Below is an instruction that describes a task....            Web Dev
# 2  Below is an instruction that describes a task....            Sorting
# 3  Below is an instruction that describes a task....            Sorting
# 4  Below is an instruction that describes a task....            Sorting
#
#   category
# 0  Sorting
# 1  Web Dev
# 2  Sorting
# 3  Sorting
# 4  Sorting

# %%
import re

illegal = re.compile(r"[\x00-\x08\x0B\x0C\x0E-\x1F]")

def clean_text(text):
    if isinstance(text, str):
        return illegal.sub("", text)
    return text

df_clean = df.apply(lambda col: col.map(clean_text))
df_clean.to_excel("alpca_with_category_dataset.xlsx", index=False)
