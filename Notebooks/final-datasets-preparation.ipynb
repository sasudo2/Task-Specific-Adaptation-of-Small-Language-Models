# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/taco-cleaned/taco_cleaned.csv
# /kaggle/input/alpaca-datasets-specific-competetive-datasets/cleaned_data_2.numbers
# /kaggle/input/cleaned-datasets-of-alpaca/cleaned_data_2.csv
# /kaggle/input/python-dataset-for-dsa-questions/cleaned_flytec.csv
# /kaggle/input/leetcode-with-desciption-and-code/leetcode_with_description_and_code.csv

# %%
df1 = pd.read_csv("/kaggle/input/taco-cleaned/taco_cleaned.csv")
df2 = pd.read_csv("/kaggle/input/cleaned-datasets-of-alpaca/cleaned_data_2.csv")
df3 = pd.read_csv("/kaggle/input/leetcode-with-desciption-and-code/leetcode_with_description_and_code.csv")
df4 = pd.read_csv("/kaggle/input/python-dataset-for-dsa-questions/cleaned_flytec.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1205 non-null   int64
#  1   id                 1205 non-null   int64
#  2   title              1205 non-null   object
#  3   description        1205 non-null   object
#  4   is_premium         1205 non-null   int64
#  5   difficulty         1205 non-null   object
#  6   solution_link      733 non-null    object
#  7   acceptance_rate    1205 non-null   float64
#  8   frequency          1205 non-null   float64
#  9   url                1205 non-null   object
#  10  discuss_count      1205 non-null   int64
#  11  accepted           1205 non-null   object
#  12  submissions        1205 non-null   object
#  13  companies          1167 non-null   object
#  14  related_topics     1144 non-null   object
#  15  likes              1205 non-null   int64
#  16  dislikes           1205 non-null   int64
#  17  rating             1205 non-null   int64
#  18  asked_by_faang     1205 non-null   int64
#  19  similar_questions  543 non-null    object
#  20  code               1205 non-null   object
# dtypes: float64(2), int64(8), object(11)
# memory usage: 197.8+ KB

# %%
df3 = df3.iloc[200:1201]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 200 to 1200
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1001 non-null   int64
#  1   id                 1001 non-null   int64
#  2   title              1001 non-null   object
#  3   description        1001 non-null   object
#  4   is_premium         1001 non-null   int64
#  5   difficulty         1001 non-null   object
#  6   solution_link      546 non-null    object
#  7   acceptance_rate    1001 non-null   float64
#  8   frequency          1001 non-null   float64
#  9   url                1001 non-null   object
#  10  discuss_count      1001 non-null   int64
#  11  accepted           1001 non-null   object
#  12  submissions        1001 non-null   object
#  13  companies          964 non-null    object
#  14  related_topics     941 non-null    object
#  15  likes              1001 non-null   int64
#  16  dislikes           1001 non-null   int64
#  17  rating             1001 non-null   int64
#  18  asked_by_faang     1001 non-null   int64
#  19  similar_questions  368 non-null    object
#  20  code               1001 non-null   object
# dtypes: float64(2), int64(8), object(11)
# memory usage: 164.4+ KB

# %%
df3 = df3[['description', 'code']]

# %%
df4 = df4.iloc[:4000]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  4000 non-null   object
#  1   code         4000 non-null   object
#  2   category     4000 non-null   object
# dtypes: object(3)
# memory usage: 93.9+ KB

# %%
df4 = df4[['instruction','code']]

# %%
df2 = df2.iloc[:5000]

# %%
df2.head()
# Out:
#    Unnamed: 0                                        instruction  \
# 0           0  Create a function to calculate the sum of a se...
# 1           2  Create a Python list comprehension to get the ...
# 2           3   Generate a python script to perform this action.
# 3           4  Write a python script to generates random numb...
# 4           5  Write a Python code to get the third largest e...
#
#                                                input  \
# 0                                    [1, 2, 3, 4, 5]
# 1                                                NaN
# 2  Given a string, remove all the consecutive dup...
# 3                                                NaN
# 4                           [12, 13, 13, 45, 22, 99]
#
#                                               output  \
# 0  # Python code\ndef sum_sequence(sequence):\n  ...
# 1                 [x*x for x in [1, 2, 3, 5, 8, 13]]
# 2  def remove_duplicates(string): \n    result = ...
# 3  def generate_random_divisible_number():\n    i...
# 4  def third_largest(lst):\n    if len(lst) < 3:\...
#
#                                               prompt classification_raw  \
# 0  Below is an instruction that describes a task....            Sorting
# 1  Below is an instruction that describes a task....            Sorting
# 2  Below is an instruction that describes a task....            Sorting
# 3  Below is an instruction that describes a task....            Sorting
# 4  Below is an instruction that describes a task....            Sorting
#
#   category
# 0  Sorting
# 1  Sorting
# 2  Sorting
# 3  Sorting
# 4  Sorting

# %%
df2 = df2[['instruction','output']]

# %%
df1 = df1.iloc[:15000]

# %%
df1.head()
# Out:
#                                             question  \
# 0  The city park of IT City contains n east to we...
# 1  Zookeeper is buying a carton of fruit to feed ...
# 2  Sasha and Kolya decided to get drunk with Coke...
# 3  Read problem statements in [Hindi], [Bengali],...
# 4  I started this as a joke among friends, tellin...
#
#                                            solutions
# 0  n = int(input())\ncn5 = n * (n - 1) // 2 * (n ...
# 1  hist = [0] * 1000005\n\ndef solve(n, s):\n\tto...
# 2  from collections import deque\nMAX_A = 1000\n\...
# 3  p = 10 ** 9 + 7\n\ndef power(a, n):\n\tres = 1...
# 4  from math import *\nDIGS = '0123456789ABCDEFGH...

# %%
df1 = df1[['question','solutions']]

# %%
df1 = df1.rename(columns={'question': 'instruction', 'solutions': 'code'})
df2 = df2.rename(columns={'instruction': 'instruction', 'output': 'code'})
df3 = df3.rename(columns={'description': 'instruction', 'code': 'code'})

# %%
combined_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
combined_df.head()
# Out:
#                                          instruction  \
# 0  The city park of IT City contains n east to we...
# 1  Zookeeper is buying a carton of fruit to feed ...
# 2  Sasha and Kolya decided to get drunk with Coke...
# 3  Read problem statements in [Hindi], [Bengali],...
# 4  I started this as a joke among friends, tellin...
#
#                                                 code
# 0  n = int(input())\ncn5 = n * (n - 1) // 2 * (n ...
# 1  hist = [0] * 1000005\n\ndef solve(n, s):\n\tto...
# 2  from collections import deque\nMAX_A = 1000\n\...
# 3  p = 10 ** 9 + 7\n\ndef power(a, n):\n\tres = 1...
# 4  from math import *\nDIGS = '0123456789ABCDEFGH...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25001 entries, 0 to 25000
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  25001 non-null  object
#  1   code         25001 non-null  object
# dtypes: object(2)
# memory usage: 390.8+ KB

# %%
shuffled_df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
train = shuffled_df.iloc[0:18000]

# %%
validation = shuffled_df.iloc[18000:21500]

# %%
test = shuffled_df.iloc[21500:]

# %%
test.head()
# Out:
#                                              instruction  \
# 21500  William has a favorite bracket sequence. Since...
# 21501  You are given an array [A_{1}, \ldots, A_{N}]....
# 21502  Write a program to calculate values of arithme...
# 21503  Manasa is a student in the department of Mathe...
# 21504  Read problems statements in Mandarin chinese, ...
#
#                                                     code
# 21500  from os import path\nfrom io import BytesIO, I...
# 21501  t = int(input())\nwhile t > 0:\n\tt -= 1\n\tn ...
# 21502  OVER = 10000\n\ndef factor():\n\tglobal w, pos...
# 21503  P = 10 ** 9 + 7\nn = int(input())\ndata = [map...
# 21504  def f(h):\n\tif h == 1:\n\t\treturn 1\n\telif ...

# %%
import json  # <- this was missing

# Write to JSONL
with open("train.jsonl", "w", encoding="utf-8") as f:
    for _, row in train.iterrows():
        obj = {
            "instruction": str(row['instruction']),
            "code": str(row['code'])
        }
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

print("JSONL file created: train.jsonl")
# Out:
# JSONL file created: train.jsonl

# %%
import json  # <- this was missing

# Write to JSONL
with open("validation.jsonl", "w", encoding="utf-8") as f:
    for _, row in validation.iterrows():
        obj = {
            "instruction": str(row['instruction']),
            "code": str(row['code'])
        }
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

print("JSONL file created: validation.jsonl")
# Out:
# JSONL file created: validation.jsonl

# %%
import json  # <- this was missing

# Write to JSONL
with open("test.jsonl", "w", encoding="utf-8") as f:
    for _, row in test.iterrows():
        obj = {
            "instruction": str(row['instruction']),
            "code": str(row['code'])
        }
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

print("JSONL file created: test.jsonl")
# Out:
# JSONL file created: test.jsonl
